# %%
import re
import pandas as pd

# %%
# Directorio con la carpeta donde se encuentran los datos. Cambiar si fuera necesario.
work_folder = '/Directorio/SL_Data/'

# %%
# Genes esenciales (Selección negativa) y supresores (Selección positiva) inferidos del análisis de MAGeCKFlute.

# PatuT. Genes esenciales:
PatuTEss = ['PRMT3','ASXL1','HELLS','SMARCE1','KDM4B','EPC2']
# PatuT. Genes supresores:
PatuTSup = ['WHSC1','SUV39H2']

# PatuS. Genes esenciales:
PatuSEss = ['CHD7','BRD4','ING5']
# PatuS. Genes supresores:
PatuSSup = ['PHF23','UBE2A']

# %%
# Función que comprueba si de dentre los genes de una lista de parejas de SL se encuentran los introducidos, y devuelve la lista de parejas completa.
def SLfinder(df, gene):
    n2 = df.loc[df['n1.name'] == gene, 'n2.name']
    n1 = df.loc[df['n2.name'] == gene, 'n1.name']
    n = list(n2) + list(n1)
    if len(n) > 0:
        return n
    else:
        return 'No SL pairs Found'

# %%
# Función que aplica la función SLfiner() a la lista de genes definidos anteriormente 
# usando los datos introducidos de una base de datos concreta. Después guarda las parejas
# encontradas por cada gen en un archivo .csv.
def SLcsv(df,db):
    SL_results = {}

    print(f'-------SL pairs for Essential PatuT Genes in {db}:')
    print()
    for gene in PatuTEss:
        SLpairsTEssAll = SLfinder(df, gene)
        print(f'SL pairs in {db} for {gene}: {SLpairsTEssAll}')
        if isinstance(SLpairsTEssAll, list):
            SL_results[gene] = SLpairsTEssAll
        print()
    
    print(f'-------SL pairs for Suppressor PatuT Genes in {db}:')
    print()
    for gene in PatuTSup:
        SLpairsTSupAll = SLfinder(df, gene)
        print(f'SL pairs in {db} for {gene}: {SLpairsTSupAll}')
        if isinstance(SLpairsTSupAll, list):
            SL_results[gene] = SLpairsTSupAll
        print()

    print(f'-------SL pairs for Essential PatuS Genes in {db}:')
    print()
    for gene in PatuSEss:
        SLpairsSEssAll = SLfinder(df, gene)
        print(f'SL pairs in {db} for {gene}: {SLpairsSEssAll}')
        if isinstance(SLpairsSEssAll, list):
            SL_results[gene] = SLpairsSEssAll
        print()

    print(f'-------SL pairs for Suppressor PatuS Genes in {db}:')
    print()
    for gene in PatuSSup:
        SLpairsSSupAll = SLfinder(df, gene)
        print(f'SL pairs in {db} for {gene}: {SLpairsSSupAll}')
        if isinstance(SLpairsSSupAll, list):
            SL_results[gene] = SLpairsSSupAll
        print()

    if len(SL_results) != 0:

        SL_results = pd.DataFrame.from_dict(SL_results, orient = 'index').T
        SL_results = SL_results.map(lambda x: '' if x is None else x)
        SL_results.to_csv(f'{work_folder}Candidate_SL_Pairs/{db}_SLPairs.csv', header = True, index = False)

# %% [markdown]
# # SynLethDB

# %%
# Carga de los datos de SynLethDB.
SLdb = pd.read_csv(f'{work_folder}SynLethDB/Human_SL.csv')
print(SLdb)
# Out:
#        n1.name  n1.identifier  n2.name  n2.identifier r.cell_line r.pubmed_id  \
# 0      TMEM35A          59353     PTEN           5728         NaN    26427375
# 1      TMEM35A          59353    BRCA2            675         NaN    26427375
# 2        CIDEA           1149     NAE1           8883        A375    23100467
# 3         FHL5           9457    OPRK1           4986         NaN    25171417
# 4         FHL5           9457    GHRHR           2692         NaN    25171417
# ...        ...            ...      ...            ...         ...         ...
# 35938    PRKCQ           5588  SLC22A1           6580   K562;K562    20609354
# 35939   RNF19A          25897     TP53           7157         NaN    26427375
# 35940  SLC10A7          84068      ATM            472         NaN    26427375
# 35941     SVIL           6840     PTEN           5728         NaN    26427375
# 35942     SVIL           6840     CAV2            858         NaN    25171417
#
#                        r.source  r.statistic_score
# 0      Computational Prediction                0.3
# 1      Computational Prediction                0.3
# 2                    GenomeRNAi                0.5
# 3      Computational Prediction                0.3
# 4      Computational Prediction                0.3
# ...                         ...                ...
# 35938                GenomeRNAi              521.0
# 35939  Computational Prediction                0.3
# 35940  Computational Prediction                0.3
# 35941  Computational Prediction                0.3
# 35942  Computational Prediction                0.3
#
# [35943 rows x 8 columns]

# %%
# Obtención de una lista con todos los posibles orígenes de cada pareja registarda en SynLethDB.
SLdbSource = SLdb['r.source'].astype('category')
Source_list = SLdbSource.cat.categories.tolist()

Source_types = set()

# División de aquellas entradas con dos o más fuentes para obtenerlas por separado.
for source in Source_list:
    
    sources = re.split(r'[;,]', source)
    
    Source_types.update(s.strip() for s in sources)

for s in Source_types:
    print(s)
# Out:
# Text Mining
# CRISPR/CRISPRi
# GenomeRNAi
# Decipher
# High Throughput|Low Throughput
# Low Throughput
# Synlethality
# Drug Screen
# High Throughput
# Computational Prediction
# Daisy
# RNAi Screen

# %%
# Clasificación de las fuentes computacionales:
CompSources = ['Computational Prediction','Decipher;Computational Prediction','Text Mining;Daisy']

# Clasificación de las fuentes bibliográficas y/o experimentales:
ExpSources = ['CRISPR/CRISPRi','Decipher', 'Decipher;Text Mining', 'Drug Screen', 'GenomeRNAi', 'GenomeRNAi;Decipher', 'GenomeRNAi;Text Mining', 'High Throughput', 
              'High Throughput|Low Throughput', 'Low Throughput', 'RNAi Screen', 'Synlethality', 'Synlethality;Decipher', 'Synlethality;GenomeRNAi', 'Synlethality;Text Mining', 
              'Text Mining','Text Mining;Synlethality']

# Filtrado de los datos de SynLethDB según el origen de sus datos.
# Fuentes computacionales:
SLdbComp = SLdb[SLdb['r.source'].isin(CompSources)]
print(SLdbComp)
print(SLdbComp['r.source'].astype('category'))
# Fuentes bibliográficas/experimentales:
SLdbExp = SLdb[SLdb['r.source'].isin(ExpSources)]
print(SLdbExp)
print(SLdbExp['r.source'].astype('category'))
# Out:
#        n1.name  n1.identifier  n2.name  n2.identifier r.cell_line r.pubmed_id  \
# 0      TMEM35A          59353     PTEN           5728         NaN    26427375
# 1      TMEM35A          59353    BRCA2            675         NaN    26427375
# 3         FHL5           9457    OPRK1           4986         NaN    25171417
# 4         FHL5           9457    GHRHR           2692         NaN    25171417
# 5         FHL5           9457  SLC13A1           6561         NaN    25171417
# ...        ...            ...      ...            ...         ...         ...
# 35934    NUP88           4927    DHX36         170506         NaN    31340155
# 35939   RNF19A          25897     TP53           7157         NaN    26427375
# 35940  SLC10A7          84068      ATM            472         NaN    26427375
# 35941     SVIL           6840     PTEN           5728         NaN    26427375
# 35942     SVIL           6840     CAV2            858         NaN    25171417
#
#                        r.source  r.statistic_score
# 0      Computational Prediction             0.3000
# 1      Computational Prediction             0.3000
# 3      Computational Prediction             0.3000
# 4      Computational Prediction             0.3000
# 5      Computational Prediction             0.3000
# ...                         ...                ...
# 35934  Computational Prediction             0.1227
# 35939  Computational Prediction             0.3000
# 35940  Computational Prediction             0.3000
# 35941  Computational Prediction             0.3000
# 35942  Computational Prediction             0.3000
#
# [9331 rows x 8 columns]
# 0        Computational Prediction
# 1        Computational Prediction
# 3        Computational Prediction
# 4        Computational Prediction
# 5        Computational Prediction
#                    ...
# 35934    Computational Prediction
# 35939    Computational Prediction
# 35940    Computational Prediction
# 35941    Computational Prediction
# 35942    Computational Prediction
# Name: r.source, Length: 9331, dtype: category
# Categories (3, object): ['Computational Prediction', 'Decipher;Computational Prediction', 'Text Mining;Daisy']
#       n1.name  n1.identifier  n2.name  n2.identifier r.cell_line r.pubmed_id  \
# 2       CIDEA           1149     NAE1           8883        A375    23100467
# 6      FKBP11          51303    NTRK1           4914   K562;K562    20609354
# 7      FKBP11          51303      RET           5979   K562;K562    20609354
# 8      FKBP11          51303   PDGFRA           5156   K562;K562    20609354
# 9      FKBP11          51303  SLC22A1           6580   K562;K562    20609354
# ...       ...            ...      ...            ...         ...         ...
# 35933   CEP63          80254    EIF3C           8663        K562    31300006
# 35935   PRKCQ           5588    PTGS1           5742   K562;K562    20609354
# 35936   PRKCQ           5588  SLC22A2           6582   K562;K562    20609354
# 35937   PRKCQ           5588      RET           5979   K562;K562    20609354
# 35938   PRKCQ           5588  SLC22A1           6580   K562;K562    20609354
#
#              r.source  r.statistic_score
# 2          GenomeRNAi               0.50
# 6          GenomeRNAi             506.00
# 7          GenomeRNAi             506.00
# 8          GenomeRNAi             506.00
# 9          GenomeRNAi             506.00
# ...               ...                ...
# 35933  CRISPR/CRISPRi               0.85
# 35935      GenomeRNAi             521.00
# 35936      GenomeRNAi             521.00
# 35937      GenomeRNAi             521.00
# 35938      GenomeRNAi             521.00
#
# [26612 rows x 8 columns]
# 2            GenomeRNAi
# 6            GenomeRNAi
# 7            GenomeRNAi
# 8            GenomeRNAi
# 9            GenomeRNAi
#               ...
# 35933    CRISPR/CRISPRi
# 35935        GenomeRNAi
# 35936        GenomeRNAi
# 35937        GenomeRNAi
# 35938        GenomeRNAi
# Name: r.source, Length: 26612, dtype: category
# Categories (17, object): ['CRISPR/CRISPRi', 'Decipher', 'Decipher;Text Mining', 'Drug Screen', ..., 'Synlethality;GenomeRNAi', 'Synlethality;Text Mining', 'Text Mining', 'Text Mining;Synlethality']

# %%
SLcsv(SLdbComp,'SynLethDB_Comp')
# Out:
# -------SL pairs for Essential PatuT Genes in SynLethDB_Comp:
#
# SL pairs in SynLethDB_Comp for PRMT3: No SL pairs Found
#
# SL pairs in SynLethDB_Comp for ASXL1: ['BRCA1']
#
# SL pairs in SynLethDB_Comp for HELLS: ['RFC2', 'TOPBP1', 'PCNA', 'ZNF107', 'SFPQ', 'FEN1']
#
# SL pairs in SynLethDB_Comp for SMARCE1: ['LRRC37A3']
#
# SL pairs in SynLethDB_Comp for KDM4B: ['SMARCC2', 'MED16', 'POGZ', 'DAZAP1']
#
# SL pairs in SynLethDB_Comp for EPC2: No SL pairs Found
#
# -------SL pairs for Suppressor PatuT Genes in SynLethDB_Comp:
#
# SL pairs in SynLethDB_Comp for WHSC1: No SL pairs Found
#
# SL pairs in SynLethDB_Comp for SUV39H2: ['ZWINT', 'RAD51', 'RBM17', 'KIF11', 'GTPBP4', 'ANKRD16', 'ATP5F1C']
#
# -------SL pairs for Essential PatuS Genes in SynLethDB_Comp:
#
# SL pairs in SynLethDB_Comp for CHD7: ['KCNJ8', 'HBG1', 'PRTN3']
#
# SL pairs in SynLethDB_Comp for BRD4: ['PRKCSH', 'GGA3', 'CCNT1', 'SIN3B', 'TP53', 'TNK2']
#
# SL pairs in SynLethDB_Comp for ING5: ['MRPS25']
#
# -------SL pairs for Suppressor PatuS Genes in SynLethDB_Comp:
#
# SL pairs in SynLethDB_Comp for PHF23: ['GPS2']
#
# SL pairs in SynLethDB_Comp for UBE2A: ['WDR44']

# %%
SLcsv(SLdbExp,'SynLethDB_Exp')
# Out:
# -------SL pairs for Essential PatuT Genes in SynLethDB_Exp:
#
# SL pairs in SynLethDB_Exp for PRMT3: No SL pairs Found
#
# SL pairs in SynLethDB_Exp for ASXL1: ['MUS81']
#
# SL pairs in SynLethDB_Exp for HELLS: No SL pairs Found
#
# SL pairs in SynLethDB_Exp for SMARCE1: No SL pairs Found
#
# SL pairs in SynLethDB_Exp for KDM4B: No SL pairs Found
#
# SL pairs in SynLethDB_Exp for EPC2: No SL pairs Found
#
# -------SL pairs for Suppressor PatuT Genes in SynLethDB_Exp:
#
# SL pairs in SynLethDB_Exp for WHSC1: No SL pairs Found
#
# SL pairs in SynLethDB_Exp for SUV39H2: ['KRAS', 'NRAS', 'HRAS']
#
# -------SL pairs for Essential PatuS Genes in SynLethDB_Exp:
#
# SL pairs in SynLethDB_Exp for CHD7: ['KRAS', 'NRAS', 'HRAS']
#
# SL pairs in SynLethDB_Exp for BRD4: ['MYC', 'PTAR1', 'PARP1', 'NAE1', 'KMT2D', 'MSH6', 'KDM5C', 'PTEN', 'MAP2K1', 'FGFR3', 'RB1', 'DHFR', 'CHEK2', 'CDC7', 'BRCA1', 'CDK9', 'CHEK1', 'WEE1']
#
# SL pairs in SynLethDB_Exp for ING5: ['CDC7', 'TUBA1A', 'MAP2K1', 'CDK9']
#
# -------SL pairs for Suppressor PatuS Genes in SynLethDB_Exp:
#
# SL pairs in SynLethDB_Exp for PHF23: No SL pairs Found
#
# SL pairs in SynLethDB_Exp for UBE2A: ['NAE1']

# %% [markdown]
# # Slorth

# %%
# Carga de los datos de Slorth:
SLslorth = pd.read_csv(f'Slorth/h.sapiens_ssl_predictions.csv', sep = '\t', header = None)
print(SLslorth)
# Out:
#                0       1                2                3           4  \
# 0          CHEK1    MTOR  ENSG00000149554  ENSG00000198793  H. sapiens
# 1            ADA   CHEK1  ENSG00000196839  ENSG00000149554  H. sapiens
# 2          BRCA1   PARP1  ENSG00000012048  ENSG00000143799  H. sapiens
# 3          BRCA2   PARP1  ENSG00000139618  ENSG00000143799  H. sapiens
# 4       C10orf76   PTAR1  ENSG00000120029  ENSG00000188647  H. sapiens
# ...          ...     ...              ...              ...         ...
# 518631       TPR   U2AF1  ENSG00000047410  ENSG00000160201  H. sapiens
# 518632       TPR   VTI1A  ENSG00000047410  ENSG00000151532  H. sapiens
# 518633      TSC2   U2AF1  ENSG00000103197  ENSG00000160201  H. sapiens
# 518634      TSC2   VTI1A  ENSG00000103197  ENSG00000151532  H. sapiens
# 518635      TSC2  ZBTB16  ENSG00000103197  ENSG00000109906  H. sapiens
#
#               5                          6         7
# 0       BioGRID  2208318, 2342099, 2342170  3.000000
# 1       BioGRID           2208350, 2342104  2.000000
# 2       BioGRID           2208315, 2342182  2.000000
# 3       BioGRID           2342181, 2344243  2.000000
# 4       BioGRID           2197822, 2197871  2.000000
# ...         ...                        ...       ...
# 518631   Slorth                          -  0.822218
# 518632   Slorth                          -  0.814406
# 518633   Slorth                          -  0.816285
# 518634   Slorth                          -  0.855900
# 518635   Slorth                          -  0.743188
#
# [518636 rows x 8 columns]

# %%
# Filtrado de las parejas de Slorth con un origen experimental (BioGRID).
SLslorthExp = SLslorth[SLslorth[5] == 'BioGRID']
print(SLslorthExp)

# Filtrado de las parejas de Slorth con un origen computacional.
SLslorthComp = SLslorth[SLslorth[5] == 'Slorth']
print(SLslorthComp)
# Out:
#             0      1                2                3           4        5  \
# 0       CHEK1   MTOR  ENSG00000149554  ENSG00000198793  H. sapiens  BioGRID
# 1         ADA  CHEK1  ENSG00000196839  ENSG00000149554  H. sapiens  BioGRID
# 2       BRCA1  PARP1  ENSG00000012048  ENSG00000143799  H. sapiens  BioGRID
# 3       BRCA2  PARP1  ENSG00000139618  ENSG00000143799  H. sapiens  BioGRID
# 4    C10orf76  PTAR1  ENSG00000120029  ENSG00000188647  H. sapiens  BioGRID
# ..        ...    ...              ...              ...         ...      ...
# 928    TUBA1A  YWHAZ  ENSG00000167552  ENSG00000164924  H. sapiens  BioGRID
# 929     VEGFA    VHL  ENSG00000112715  ENSG00000134086  H. sapiens  BioGRID
# 930      WEE1   WEE1  ENSG00000166483  ENSG00000166483  H. sapiens  BioGRID
# 931      WEE1    WRN  ENSG00000166483  ENSG00000165392  H. sapiens  BioGRID
# 932      WEE1  XRCC3  ENSG00000166483  ENSG00000126215  H. sapiens  BioGRID
#
#                              6    7
# 0    2208318, 2342099, 2342170  3.0
# 1             2208350, 2342104  2.0
# 2             2208315, 2342182  2.0
# 3             2342181, 2344243  2.0
# 4             2197822, 2197871  2.0
# ..                         ...  ...
# 928                    2342226  1.0
# 929                    2208434  1.0
# 930                    2342164  1.0
# 931                    2342159  1.0
# 932                    2342166  1.0
#
# [933 rows x 8 columns]
#             0       1                2                3           4       5  \
# 933     CDC27   MYLIP  ENSG00000004897  ENSG00000007944  H. sapiens  Slorth
# 934     CDC27  NCAPD2  ENSG00000004897  ENSG00000010292  H. sapiens  Slorth
# 935     CDC27  POLR3B  ENSG00000004897  ENSG00000013503  H. sapiens  Slorth
# 936     CDC27    CDH1  ENSG00000004897  ENSG00000039068  H. sapiens  Slorth
# 937     CDC27   VAMP3  ENSG00000004897  ENSG00000049245  H. sapiens  Slorth
# ...       ...     ...              ...              ...         ...     ...
# 518631    TPR   U2AF1  ENSG00000047410  ENSG00000160201  H. sapiens  Slorth
# 518632    TPR   VTI1A  ENSG00000047410  ENSG00000151532  H. sapiens  Slorth
# 518633   TSC2   U2AF1  ENSG00000103197  ENSG00000160201  H. sapiens  Slorth
# 518634   TSC2   VTI1A  ENSG00000103197  ENSG00000151532  H. sapiens  Slorth
# 518635   TSC2  ZBTB16  ENSG00000103197  ENSG00000109906  H. sapiens  Slorth
#
#         6         7
# 933     -  0.735260
# 934     -  0.853135
# 935     -  0.861576
# 936     -  0.783209
# 937     -  0.706373
# ...    ..       ...
# 518631  -  0.822218
# 518632  -  0.814406
# 518633  -  0.816285
# 518634  -  0.855900
# 518635  -  0.743188
#
# [517703 rows x 8 columns]

# %%
# Función que ajusta el formato de las parejas para la función SLcsv().
def SLcolumns(SLdf):
    SLdf = SLdf.iloc[:,[0,1,7]]
    SLdf.columns = ['n1.name','n2.name','score']
    return SLdf

SLslorthExp = SLcolumns(SLslorthExp)
print(SLslorthExp)

SLslorthComp = SLcolumns(SLslorthComp)
print(SLslorthComp)
# Out:
#       n1.name n2.name  score
# 0       CHEK1    MTOR    3.0
# 1         ADA   CHEK1    2.0
# 2       BRCA1   PARP1    2.0
# 3       BRCA2   PARP1    2.0
# 4    C10orf76   PTAR1    2.0
# ..        ...     ...    ...
# 928    TUBA1A   YWHAZ    1.0
# 929     VEGFA     VHL    1.0
# 930      WEE1    WEE1    1.0
# 931      WEE1     WRN    1.0
# 932      WEE1   XRCC3    1.0
#
# [933 rows x 3 columns]
#        n1.name n2.name     score
# 933      CDC27   MYLIP  0.735260
# 934      CDC27  NCAPD2  0.853135
# 935      CDC27  POLR3B  0.861576
# 936      CDC27    CDH1  0.783209
# 937      CDC27   VAMP3  0.706373
# ...        ...     ...       ...
# 518631     TPR   U2AF1  0.822218
# 518632     TPR   VTI1A  0.814406
# 518633    TSC2   U2AF1  0.816285
# 518634    TSC2   VTI1A  0.855900
# 518635    TSC2  ZBTB16  0.743188
#
# [517703 rows x 3 columns]

# %%
# Filtrado de las fuentes computacionales de Slorth en base a su score de calidad
# (>= 0.75 --- High Quality Score)
SLslorthComp = SLslorthComp[SLslorthComp['score'] >= 0.75]
print(SLslorthComp)
# Out:
#        n1.name n2.name     score
# 934      CDC27  NCAPD2  0.853135
# 935      CDC27  POLR3B  0.861576
# 936      CDC27    CDH1  0.783209
# 938      CDC27  ARID1B  0.757375
# 939      CDC27  ANAPC4  0.898875
# ...        ...     ...       ...
# 518630     TPR    TSC2  0.823523
# 518631     TPR   U2AF1  0.822218
# 518632     TPR   VTI1A  0.814406
# 518633    TSC2   U2AF1  0.816285
# 518634    TSC2   VTI1A  0.855900
#
# [364720 rows x 3 columns]

# %%
SLcsv(SLslorthExp,'SlorthExp')
# Out:
# -------SL pairs for Essential PatuT Genes in SlorthExp:
#
# SL pairs in SlorthExp for PRMT3: No SL pairs Found
#
# SL pairs in SlorthExp for ASXL1: No SL pairs Found
#
# SL pairs in SlorthExp for HELLS: No SL pairs Found
#
# SL pairs in SlorthExp for SMARCE1: No SL pairs Found
#
# SL pairs in SlorthExp for KDM4B: No SL pairs Found
#
# SL pairs in SlorthExp for EPC2: No SL pairs Found
#
# -------SL pairs for Suppressor PatuT Genes in SlorthExp:
#
# SL pairs in SlorthExp for WHSC1: No SL pairs Found
#
# SL pairs in SlorthExp for SUV39H2: ['KRAS']
#
# -------SL pairs for Essential PatuS Genes in SlorthExp:
#
# SL pairs in SlorthExp for CHD7: No SL pairs Found
#
# SL pairs in SlorthExp for BRD4: ['CDC7', 'CDK9', 'CHEK1', 'CHEK2', 'DHFR', 'FGFR3', 'KDM5C', 'MAP2K1', 'PTAR1', 'PTEN', 'RB1', 'WEE1', 'BRCA1']
#
# SL pairs in SlorthExp for ING5: ['MAP2K1', 'TUBA1A', 'CDC7', 'CDK9']
#
# -------SL pairs for Suppressor PatuS Genes in SlorthExp:
#
# SL pairs in SlorthExp for PHF23: No SL pairs Found
#
# SL pairs in SlorthExp for UBE2A: No SL pairs Found

# %%
SLcsv(SLslorthComp,'SlorthComp')
# Out:
# -------SL pairs for Essential PatuT Genes in SlorthComp:
#
# SL pairs in SlorthComp for PRMT3: ['DCTN1', 'PDLIM7']
# SL pairs in SlorthComp for ASXL1: ['CDH1', 'RHOA', 'POLA1', 'SMAD4', 'PHB', 'CANX', 'SIRT1', 'PDCD6IP', 'ACTB', 'UBE2K', 'CHD4', 'POLD1', 'TXN', 'HSPA5', 'ASF1B', 'HIPK2', 'MAPK14', 'RAC1', 'SIN3B', 'PRKCB', 'HSPB1', 'MTA2', 'KDM1A', 'NFE2L2', 'HNRNPA2B1', 'TSG101', 'BMI1', 'KEAP1', 'JUND', 'EZR', 'RBL2', 'JUNB', 'SKI', 'E2F1', 'POU2F1', 'SFPQ']
#
# SL pairs in SlorthComp for HELLS: ['PSEN1', 'MAP3K1', 'ACTB', 'HSPA8', 'PRKACA', 'UBE2K', 'APEX1', 'HSPA5', 'RPS6KA1', 'CSNK1A1', 'IKBKB', 'HIPK2', 'SUPT16H', 'AURKA', 'HSPB1', 'SMARCE1', 'KDM1A', 'NFE2L2', 'TNK2', 'TSG101', 'AHR', 'SFPQ', 'TNFAIP3']
#
# SL pairs in SlorthComp for SMARCE1: ['PTPN23', 'THOC1', 'PSEN1', 'XPO1', 'HUWE1', 'SNAP23', 'MAP3K1', 'JAK2', 'SMARCB1', 'GRAP2', 'SNW1', 'PSMB5', 'HCK', 'NOP56', 'POLA1', 'NUP93', 'RNF40', 'SNRNP70', 'FBL', 'CDK6', 'MET', 'UBE2R2', 'EIF3A', 'UBTF', 'RPS6KB1', 'UBE2D3', 'FBXW7', 'ARPC3', 'CDKN1B', 'RRP9', 'NCL', 'SPTBN1', 'SOS1', 'MSH6', 'RPF1', 'ARID1A', 'RPA2', 'TJP2', 'COPS5', 'TUBA1B', 'CNOT1', 'SNRPB2', 'UBA2', 'PIN1', 'GNL3L', 'CDC16', 'UBE2M', 'UBE4B', 'UBA1', 'DCTN4', 'KRAS', 'VHL', 'CDC73', 'CDCA8', 'APC', 'WDR36', 'CDK4', 'EPRS', 'CDK9', 'NR5A1', 'RAB1A', 'ITGAV', 'USP8', 'COPS4', 'NDUFA9', 'SNRPF', 'BRCA2', 'IGF1R', 'NDUFB10', 'NCOR1', 'COPS3', 'EIF4A3', 'SMAD4', 'BRD4', 'SAE1', 'CARM1', 'PSMB6', 'PSMA5', 'PARP1', 'HSPD1', 'FANCD2', 'CCNA2', 'RBMX', 'NOTCH1', 'ATM', 'CHEK1', 'ANAPC1', 'EEF1A1', 'BUB1B', 'KIT', 'BRAF', 'PINK1', 'RUNX1', 'NXF1', 'JAK1', 'RCHY1', 'PRKCD', 'PBRM1', 'COG5', 'DCAF13', 'TSC1', 'COPS2', 'CCT2', 'WEE1', 'PLK1', 'GATAD2A', 'COPS6', 'RFWD3', 'COG7', 'MAP2K1', 'BCL2', 'EXOSC10', 'RRM2', 'PTEN', 'QARS', 'TOMM20', 'RAB1B', 'TYMS', 'ERN1', 'EXOSC4', 'GAK', 'CALR', 'NOP10', 'IST1', 'CHEK2', 'EIF3C', 'EPOR', 'FANCA', 'IARS', 'PTPN1', 'HDAC2', 'AP2A1', 'PSMD12', 'COPS8', 'MTOR', 'TOP1', 'SNX2', 'PPP2R2A', 'PRKDC', 'COG8', 'UBA3', 'UBQLN4', 'WDHD1', 'UBE2L3', 'RPS24', 'CDC34', 'STX7', 'ARHGDIA', 'IPO9', 'PHB', 'MAP3K3', 'CANX', 'YARS', 'NUP98', 'DNAJA1', 'SIRT1', 'MCM4', 'NAPA', 'XPA', 'PDCD6IP', 'ACTB', 'XPC', 'TAF5L', 'HELZ2', 'HELLS', 'LARS', 'MCM3AP', 'AARS', 'RAB11A', 'DDX24', 'NEK2', 'TTK', 'DDX19A', 'SUGT1', 'CUL4A', 'PHF12', 'UBE2S', 'MAPK10', 'TTC1', 'PRKAR1A', 'ATP6V1B2', 'PSMB7', 'PSMA3', 'CDC7', 'PSMB4', 'FEN1', 'SGK1', 'RAN', 'PSMC3', 'NLK', 'RBBP5', 'MAP2K2', 'PSMD8', 'RASA1', 'SMARCC2', 'WWP2', 'PSMA6', 'MKNK1', 'USP46', 'PRDX1', 'FOXO1', 'TUBA3E', 'VDAC1', 'GGA2', 'TRMT1', 'BTRC', 'SRSF6', 'MLST8', 'BARD1', 'MAP3K4', 'SRSF4', 'RAD17', 'PSMC2', 'UBQLN1', 'TKT', 'UBR5', 'KAT5', 'PRMT1', 'RPS29', 'SSRP1', 'TAF9', 'H2AFX', 'RPS6KA3', 'ARHGEF2', 'CTBP2', 'PSMA8', 'HSPA8', 'EXOSC2', 'VRK1', 'NOLC1', 'CHMP5', 'PRKACB', 'CFL1', 'TIAL1', 'TUBB2A', 'ACTG1', 'HDAC5', 'RPL13A', 'MCM5', 'NCAPH', 'SNRNP200', 'RBM22', 'HCFC1', 'RAB11B', 'ARF6', 'PSMC1', 'CHD3', 'CHMP1A', 'RAD23B', 'COPB1', 'RPS7', 'DNM1', 'EFTUD2', 'VAV2', 'RPL36', 'RAC3', 'CUL5', 'PRKCI', 'ACTL6B', 'MAP2K6', 'TOP2A', 'TAF1', 'PFDN5', 'UBE2K', 'MYB', 'H3F3A', 'USP22', 'SENP2', 'EP400', 'EDF1', 'PPP2R5D', 'DDX56', 'CHD4', 'SRSF5', 'POLE3', 'CYCS', 'STRN4', 'UBE2N', 'AIMP1', 'RPS14', 'POLR3A', 'TERT', 'COPA', 'TXN', 'APEX1', 'CTBP1', 'UBE2V1', 'BECN1', 'RNF20', 'ESPL1', 'CALM1', 'EIF4E', 'ING1', 'HSPA2', 'HSP90AB1', 'CKS2', 'NDC80', 'CSTF2', 'CDC25B', 'PSMD7', 'ASF1B', 'HGS', 'EZH2', 'SEPT2', 'CDC25C', 'EXO1', 'PSMD9', 'LEO1', 'RPA1', 'MYBL2', 'STRIP1', 'CUL2', 'RAD23A', 'YWHAH', 'RPS6KA1', 'HSPA6', 'ACTA1', 'CSNK1D', 'BUB3', 'CKAP5', 'CCNB1', 'CLINT1', 'CDC23', 'HIST2H2AC', 'PDPK1', 'KAT2B', 'WWP1', 'USP34', 'RCC1', 'UBXN2B', 'TBP', 'DAD1', 'DNA2', 'EIF2B2', 'EIF3B', 'HAT1', 'MSH2', 'ASCC3', 'CSNK1A1', 'TGFBRAP1', 'EIF2S1', 'SETX', 'CDK7', 'DMAP1', 'ERCC4', 'SF1', 'MAD2L1', 'GGA1', 'SYVN1', 'SMC4', 'PPIF', 'PRKCA', 'VPS25', 'CDC45', 'GNAQ', 'ATR', 'YWHAQ', 'POLR2C', 'SSU72', 'ENO1', 'HERC2', 'GNA13', 'CDC6', 'STX4', 'KPNB1', 'MCM7', 'BLM', 'AMFR', 'PPIA', 'TUBA4A', 'UBE2B', 'CHUK', 'BUB1', 'COPB2', 'PSMC5', 'EIF4G1', 'PSMD3', 'AP2A2', 'PRPF6', 'UBE3A', 'HMGB1', 'EEF1G', 'RFC4', 'SSB', 'SEPT11', 'AP1B1', 'ASNA1', 'POLR1E', 'ING5', 'RANGAP1', 'NSFL1C', 'CEBPZ', 'UBE2V2', 'KHDRBS1', 'ING4', 'PAK1', 'RRP1B', 'PRKAR2A', 'NAP1L1', 'SLX1A', 'DCTN1', 'RAB7A', 'MAP3K2', 'STIP1', 'ORC1', 'PSMC6', 'NCAPG', 'H2AFV', 'SRCAP', 'SRSF9', 'SPATA5', 'ERCC2', 'RANBP2', 'VCP', 'DDX1', 'PSMD11', 'INPP5D', 'EIF4G2', 'PPID', 'EHMT2', 'CDC25A', 'NUP107', 'UBE2E3', 'PSMB10', 'SRSF1', 'RBMS2', 'FAF2', 'CHTF18', 'FZR1', 'GNL3', 'TCP1', 'AP2M1', 'UBL5', 'RAB8A', 'SHMT2', 'CNOT8', 'CSTF3', 'GSK3A', 'MAP3K5', 'CYC1', 'PRKCE', 'TTC37', 'NAPB', 'TXNL1', 'PPM1B', 'WW ...
#
# SL pairs in SlorthComp for KDM4B: ['KRAS', 'CASP7', 'SIAH2', 'IDE', 'BCLAF1']
#
# SL pairs in SlorthComp for EPC2: ['SRCAP', 'TAF1L', 'EPC1']
#
# -------SL pairs for Suppressor PatuT Genes in SlorthComp:
#
# SL pairs in SlorthComp for WHSC1: ['FGFR2', 'PRKACA', 'HDAC9', 'TCF3', 'KDM1A', 'PRDM1']
#
# SL pairs in SlorthComp for SUV39H2: No SL pairs Found
#
# -------SL pairs for Essential PatuS Genes in SlorthComp:
#
# SL pairs in SlorthComp for CHD7: No SL pairs Found
#
# SL pairs in SlorthComp for BRD4: ['FANCD2', 'FOXO1', 'PRKCI', 'SF1', 'AURKB', 'PRKCB', 'OGT', 'BMI1', 'SREBF2', 'MYD88', 'DDIT3', 'CDC27', 'CDH1', 'CTDP1', 'CASP8', 'FGFR2', 'UBE2D1', 'GSK3B', 'XPO1', 'JAK2', 'ABL1', 'SMARCB1', 'MAPK1', 'POLA1', 'UBE2I', 'SNRNP70', 'UBE2D3', 'FBXW7', 'CDKN1B', 'NCL', 'HDAC1', 'RPA2', 'COPS5', 'ZC3H13', 'CDK2', 'PIN1', 'UBA1', 'RAF1', 'VHL', 'APC', 'CDK4', 'MYC', 'NCOR1', 'EIF4A3', 'SMAD4', 'ERBB2', 'CDC34', 'SIRT1', 'MCM4', 'CUL4A', 'CDC7', 'RAN', 'PCNA', 'BARD1', 'CSNK2A1', 'UBQLN1', 'PRMT1', 'HSPA8', 'CUL1', 'UBE2D2', 'RAD23B', 'EFTUD2', 'PRKACA', 'TOP2A', 'UBE2K', 'POLD1', 'APEX1', 'HSP90AB1', 'SUMO1', 'ASF1B', 'EZH2', 'RPA1', 'CUL2', 'RPS6KA1', 'CCNB1', 'KAT2B', 'WWP1', 'TBP', 'MSH2', 'PABPC1', 'CDC45', 'CDC6', 'KPNB1', 'UBE2B', 'EIF4G1', 'PRPF6', 'UBE3A', 'KHDRBS1', 'IKBKB', 'ORC1', 'HIPK2', 'ERCC2', 'SRSF1', 'NEDD4', 'MAPK14', 'DYNLL1', 'MCM2', 'NEDD8', 'NCBP1', 'TOP2B', 'NEDD4L', 'NCBP2', 'ITCH', 'SUPT16H', 'RAD18', 'POLR2E', 'CREBBP', 'RECQL', 'MAPK3', 'PRPF19', 'ACTL6A', 'CDC20', 'PPP2CA', 'PIAS4', 'RAC1', 'FOXO3', 'CCNE1', 'SIN3B', 'UPF1', 'USP10', 'PIAS2', 'FKBP1A', 'AURKA', 'SUV39H1', 'CFTR', 'MORF4L2', 'CBL', 'HSPB1', 'SMAD7', 'CBLB', 'POLR2B', 'SMARCE1', 'TCF3', 'AXIN1', 'RNF2', 'ETS1', 'KDM1A', 'NFKBIA', 'PSME3', 'NFE2L2', 'PTBP1', 'ARRB1', 'FYN', 'YY1', 'MAP3K7', 'RARA', 'CCND1', 'KDR', 'SMARCA2', 'ARRB2', 'TNK2', 'PDGFRB', 'TRIM28', 'SLC9A3R1', 'RBX1', 'HIF1A', 'XIAP', 'STAT5A', 'BIRC2', 'YAP1', 'DHX9', 'PXN', 'AHR', 'RUNX2', 'PLCG1', 'KEAP1', 'BIRC3', 'SKP1', 'YBX1', 'MYOD1', 'NFKB1', 'PARK7', 'RBL2', 'VDR', 'HNRNPD', 'HNRNPA1', 'RBBP7', 'U2AF2', 'E2F1', 'CBX5', 'CREB1', 'SREBF1', 'DDX17', 'AGO2', 'BCL3', 'BCL6', 'CDKN1A', 'ESR1', 'MLLT1', 'PML', 'PPARG', 'SFPQ', 'TNFAIP3', 'TPR', 'TSC2']
#
# SL pairs in SlorthComp for ING5: ['MAP2K1', 'CALR', 'WDHD1', 'CTBP2', 'CHD3', 'MAP3K2', 'POLH', 'CKS1B', 'AURKB', 'CTNND1', 'TCF4', 'PDLIM7', 'NF2', 'JUNB', 'TFDP1', 'MYD88', 'CEBPA', 'DDIT3', 'POLE', 'PSEN1', 'XPO1', 'JAK2', 'SMARCB1', 'POLA1', 'UBE2D3', 'CDKN1B', 'RPA2', 'CDK2', 'UBA2', 'PIN1', 'VHL', 'APC', 'CDK4', 'EIF4A3', 'SMAD4', 'ERBB2', 'AKT1', 'PARP1', 'FANCD2', 'NOTCH1', 'ATM', 'CHEK1', 'BRAF', 'NXF1', 'RCHY1', 'PRKCD', 'PLK1', 'MAPK8', 'PHB', 'SIRT1', 'ACTB', 'SUGT1', 'SGK1', 'RAN', 'RBBP5', 'MAPK9', 'FOXO1', 'BARD1', 'RAD17', 'PRMT1', 'SSRP1', 'HSPA8', 'KAT7', 'PRKCI', 'MAP2K6', 'TOP2A', 'TAF1', 'UBE2K', 'H3F3A', 'POLD1', 'TERT', 'TXN', 'APEX1', 'HSPA5', 'CTBP1', 'CUL3', 'ING1', 'ASF1B', 'EZH2', 'TAF5', 'RPS6KA1', 'CSNK1D', 'CCNB1', 'KAT2B', 'KAT6A', 'DNA2', 'HAT1', 'MSH2', 'POLR1A', 'EIF2S1', 'RAD51', 'PIAS1', 'SF1', 'PRKCA', 'CDC6', 'KPNB1', 'TP53I3', 'KHDRBS1', 'ING4', 'HIPK2', 'ERCC2', 'SRSF1', 'TAF6', 'NEDD4', 'MAPK14', 'DYNLL1', 'SMG1', 'NFYA', 'ITCH', 'SUPT16H', 'CDK5', 'NFYB', 'SMC3', 'RAD18', 'MAPK3', 'HIST3H3', 'STK11', 'ACTL6A', 'TCEB1', 'MAP2K7', 'STX5', 'CCNE1', 'SIN3B', 'SMARCA5', 'UPF1', 'USP10', 'PIAS2', 'PRKCB', 'AURKA', 'EIF2AK2', 'WDR48', 'WRN', 'HDAC4', 'MORF4L2', 'OGT', 'HSPB1', 'ATP5B', 'CTNNB1', 'ACTN4', 'SMAD7', 'FGFR1', 'ATP5F1', 'SMARCE1', 'RNF2', 'ETS1', 'KDM1A', 'CDT1', 'NFE2L2', 'RPTOR', 'DTL', 'ARRB1', 'STK4', 'MAP3K7', 'TCEB2', 'RARA', 'UTRN', 'CCND1', 'EPC1', 'KDR', 'SMARCA2', 'ARRB2', 'TNK2', 'TGFB1', 'PDGFRB', 'SAP18', 'TRIM28', 'SLC9A3R1', 'HIF1A', 'XIAP', 'UFD1L', 'TP53BP2', 'YAP1', 'DHX9', 'PXN', 'AHR', 'BMI1', 'KEAP1', 'JUND', 'YBX1', 'MYOD1', 'EPAS1', 'CASP9', 'RBL2', 'VDR', 'TRIM24', 'RBBP7', 'U2AF2', 'INO80', 'CASP3', 'ERCC3', 'E2F1', 'POU2F1', 'CBX5', 'CREB1', 'DDX17', 'BCL6', 'NCOA1', 'PML', 'PPARG', 'TAL1', 'TNFAIP3', 'TPR']
#
# -------SL pairs for Suppressor PatuS Genes in SlorthComp:
#
# SL pairs in SlorthComp for PHF23: No SL pairs Found
#
# SL pairs in SlorthComp for UBE2A: ['PSEN1', 'GSK3B', 'XPO1', 'CYLD', 'HUWE1', 'SNAP23', 'MAP3K1', 'JAK2', 'ABL1', 'SMARCB1', 'MAPK1', 'GRAP2', 'PSMB5', 'HCK', 'POLA1', 'MID1', 'NAA10', 'NUP93', 'UBE2I', 'GSPT1', 'RNF40', 'SNRNP70', 'CDK6', 'MET', 'UBE2R2', 'EIF3A', 'UBTF', 'RPS6KB1', 'GOSR1', 'UBE2D3', 'FBXW7', 'ARPC3', 'CDKN1B', 'HSPA9', 'RRP9', 'NCL', 'SPTBN1', 'SOS1', 'MSH6', 'RPF1', 'RPA2', 'TJP2', 'COPS5', 'CDK2', 'TUBA1B', 'CNOT1', 'SNRPB2', 'UBA2', 'PIN1', 'GNL3L', 'CDC16', 'UBE2M', 'UBE4B', 'UBA1', 'RAF1', 'DCTN4', 'KRAS', 'VHL', 'CDC73', 'CDCA8', 'APC', 'WDR36', 'CDK4', 'EPRS', 'CDK9', 'MYC', 'RAB1A', 'ACTR2', 'ITGAV', 'USP8', 'COPS4', 'NDUFA9', 'SNRPF', 'BRCA2', 'IGF1R', 'NDUFB10', 'NCOR1', 'COPS3', 'EIF4A3', 'SMAD4', 'ERBB2', 'SAE1', 'CARM1', 'PSMB6', 'PSMA5', 'PARP1', 'HSPD1', 'FANCD2', 'CCNA2', 'MARCH6', 'RBMX', 'NOTCH1', 'ATM', 'CHEK1', 'UBE3B', 'ANAPC1', 'EEF1A1', 'BUB1B', 'KIT', 'BRAF', 'PINK1', 'RUNX1', 'SHC1', 'NXF1', 'JAK1', 'ARPC2', 'RCHY1', 'PRKCD', 'PBRM1', 'DCAF13', 'TSC1', 'COPS2', 'CCT2', 'WEE1', 'PLK1', 'GATAD2A', 'COPS6', 'RFWD3', 'MAP2K1', 'BCL2', 'EXOSC10', 'PTEN', 'QARS', 'RAB1B', 'UBE2O', 'TYMS', 'ERN1', 'EXOSC4', 'GAK', 'CALR', 'SETD2', 'IST1', 'CHEK2', 'EIF3C', 'EPOR', 'FANCA', 'IARS', 'HDAC2', 'AP2A1', 'PSMD12', 'COPS8', 'MTOR', 'TOP1', 'SNX2', 'PPP2R2A', 'PRKDC', 'UBA3', 'UBQLN4', 'WDHD1', 'UBE2L3', 'CDC34', 'STX7', 'MAPK8', 'ARHGDIA', 'IPO9', 'UBE2G1', 'PHB', 'MAP3K3', 'CANX', 'YARS', 'NUP98', 'DNAJA1', 'SIRT1', 'MCM4', 'NAPA', 'XPA', 'PDCD6IP', 'XPC', 'TAF5L', 'HELZ2', 'LARS', 'DLAT', 'MCM3AP', 'AARS', 'RAB11A', 'ATP6V1B1', 'DDX24', 'NEK2', 'TTK', 'SUGT1', 'CUL4A', 'GTF2H2C', 'UBE2S', 'MAPK10', 'TTC1', 'PRKAR1A', 'ATP6V1B2', 'PSMB7', 'PSMA3', 'CDC7', 'PSMB4', 'FEN1', 'SGK1', 'RAN', 'RAB25', 'PSMC3', 'NLK', 'RBBP5', 'MAP2K2', 'PSMD8', 'SMARCC2', 'WWP2', 'PSMA6', 'MKNK1', 'USP46', 'PRDX1', 'FOXO1', 'TUBA3E', 'VDAC1', 'GGA2', 'TRMT1', 'BTRC', 'SRSF6', 'MLST8', 'BARD1', 'MAP3K4', 'SRSF4', 'RAD17', 'PSMC2', 'UBQLN1', 'UBR5', 'KAT5', 'PRMT1', 'RPS29', 'SSRP1', 'HDAC3', 'BRSK1', 'TAF9', 'H2AFX', 'RPS6KA3', 'FASN', 'ARHGEF2', 'CTBP2', 'PSMA8', 'HSPA8', 'EXOSC2', 'NOLC1', 'CHMP5', 'PRKACB', 'CFL1', 'TUBB2A', 'ACTG1', 'RPL13A', 'HSPA4', 'MCM5', 'NCAPH', 'SNRNP200', 'RBM22', 'HCFC1', 'CHMP1B', 'RAB11B', 'ARF6', 'UBE2D2', 'PSMC1', 'CHD3', 'CHMP1A', 'RAD23B', 'COPB1', 'DNM1', 'EFTUD2', 'VAV2', 'RPL36', 'RAC3', 'CUL5', 'PRKCI', 'MAP2K6', 'TOP2A', 'TAF1', 'PFDN5', 'UBE2K', 'MYB', 'YWHAZ', 'H3F3A', 'USP22', 'SENP2', 'EP400', 'PPP2R5D', 'DDX56', 'CHD4', 'MAP1LC3C', 'SRSF5', 'POLE3', 'CYCS', 'STRN4', 'UBE2N', 'AIMP1', 'RPS14', 'POLR3A', 'TERT', 'COPA', 'TXN', 'APEX1', 'PPP6R1', 'CTBP1', 'UBE2V1', 'BECN1', 'RNF20', 'ESPL1', 'CALM1', 'EIF4E', 'YWHAB', 'ING1', 'HSPA2', 'SUCLA2', 'HSP90AB1', 'PC', 'CKS2', 'NDC80', 'CSTF2', 'CDC25B', 'PSMD7', 'ASF1B', 'HGS', 'EZH2', 'PPP2R5C', 'SEPT2', 'CDC25C', 'TAF5', 'EXO1', 'PSMD9', 'LEO1', 'STRIP1', 'CUL2', 'RAD23A', 'YWHAH', 'CALM2', 'RPS6KA1', 'HSPA6', 'ACTA1', 'CSNK1D', 'BUB3', 'TUBG1', 'CCNB1', 'CLINT1', 'CDC23', 'HIST2H2AC', 'PDPK1', 'KAT2B', 'WWP1', 'USP34', 'RCC1', 'TRIB3', 'UBXN2B', 'TBP', 'DNA2', 'EIF2B2', 'EIF3B', 'HAT1', 'MSH2', 'ASCC3', 'CSNK1A1', 'RPL22L1', 'TGFBRAP1', 'PIM1', 'EIF2S1', 'ERCC4', 'SF1', 'MAD2L1', 'GGA1', 'SYVN1', 'SMC4', 'PPIF', 'PRKCA', 'VPS25', 'CDC45', 'GNAQ', 'ATR', 'YWHAQ', 'POLR2C', 'SEC23A', 'HERC2', 'CDC6', 'STX4', 'KPNB1', 'MCM7', 'BLM', 'AMFR', 'PTRH2', 'TUBA4A', 'AKT2', 'UBE2B', 'CHUK', 'BUB1', 'COPB2', 'RPS25', 'PSMC5', 'EIF4G1', 'PSMD3', 'AP2A2', 'PRPF6', 'UBE3A', 'GCN1', 'GRK2', 'ACTC1', 'EEF1G', 'RFC4', 'SSB', 'SEPT11', 'AP1B1', 'ASNA1', 'PPP2R5E', 'POLR1E', 'VAV1', 'RANGAP1', 'NSFL1C', 'CEBPZ', 'UBE2V2', 'KHDRBS1', 'IKBKB', 'RRP1B', 'PRKAR2A', 'NAP1L1', 'SLX1A', 'DCTN1', 'GABARAP', 'ARFGAP3', 'MAP3K2', 'STIP1', 'ORC1', 'PSMC6', 'NCAPG', 'H2AFV', 'SRCAP', 'SRSF9', 'SPATA5', 'ERCC2', 'RANBP2', 'VCP', 'PSMD11', 'TOM1L1', 'ARCN1', 'INPP5D', 'EIF4G2', 'PPID', 'EHMT2', 'CDC25A', 'NUP107', 'UBE2E3', 'PSMB10', 'SRSF1', 'FAF2', 'CHTF18', ' ...

# %% [markdown]
# # DAISY

# %%
# Carga de los datos de DAISY.
SLdaisy = pd.read_csv(f'{work_folder}DAISY/DAISY_SLpairs.csv')
print(SLdaisy)
# Out:
#       Gene A   Gene B
# 0      ACAP1     DEF6
# 1      ACAP1   GIMAP1
# 2      ACAP1   MAP4K1
# 3      ACAP1   SEMA4A
# 4        ACD  SMARCC2
# ...      ...      ...
# 2811  ZNF407    MEOX2
# 2812  ZC3H7B    MUTYH
# 2813  ZNF593  MYBBP1A
# 2814  ZC3H7B    RNF40
# 2815   ZWINT     SKP2
#
# [2816 rows x 2 columns]

# %%
SLdaisy = SLdaisy.rename(columns = {'Gene A':'n1.name','Gene B':'n2.name'})
print(SLdaisy)
# Out:
#      n1.name  n2.name
# 0      ACAP1     DEF6
# 1      ACAP1   GIMAP1
# 2      ACAP1   MAP4K1
# 3      ACAP1   SEMA4A
# 4        ACD  SMARCC2
# ...      ...      ...
# 2811  ZNF407    MEOX2
# 2812  ZC3H7B    MUTYH
# 2813  ZNF593  MYBBP1A
# 2814  ZC3H7B    RNF40
# 2815   ZWINT     SKP2
#
# [2816 rows x 2 columns]

# %%
SLcsv(SLdaisy,'DAISY')
# Out:
# -------SL pairs for Essential PatuT Genes in DAISY:
#
# SL pairs in DAISY for PRMT3: No SL pairs Found
#
# SL pairs in DAISY for ASXL1: No SL pairs Found
#
# SL pairs in DAISY for HELLS: ['PCNA', 'RFC2', 'SFPQ', 'TOPBP1', 'ZNF107', 'FEN1']
#
# SL pairs in DAISY for SMARCE1: No SL pairs Found
#
# SL pairs in DAISY for KDM4B: ['POGZ', 'SMARCC2']
#
# SL pairs in DAISY for EPC2: No SL pairs Found
#
# -------SL pairs for Suppressor PatuT Genes in DAISY:
#
# SL pairs in DAISY for WHSC1: ['EZH2', 'CDCA3']
#
# SL pairs in DAISY for SUV39H2: ['RAD51']
#
# -------SL pairs for Essential PatuS Genes in DAISY:
#
# SL pairs in DAISY for CHD7: No SL pairs Found
#
# SL pairs in DAISY for BRD4: ['CCNT1', 'GGA3', 'TNK2']
#
# SL pairs in DAISY for ING5: ['MRPS25']
#
# -------SL pairs for Suppressor PatuS Genes in DAISY:
#
# SL pairs in DAISY for PHF23: No SL pairs Found
#
# SL pairs in DAISY for UBE2A: No SL pairs Found

# %% [markdown]
# # BioGrid

# %%
# Carga de los datos de BioGRID-
Databg = pd.read_csv(f'{work_folder}BIOGRID-ORGANISM-4.4.227.tab3/BIOGRID-ORGANISM-Homo_sapiens-4.4.227.tab3.txt',sep = '\t')
print(Databg)
# Out:
# /tmp/ipykernel_17508/204943909.py:1: DtypeWarning: Columns (1,2,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   Databg = pd.read_csv(f'{work_folder}BIOGRID-ORGANISM-4.4.227.tab3/BIOGRID-ORGANISM-Homo_sapiens-4.4.227.tab3.txt',sep = '\t')
#          #BioGRID Interaction ID Entrez Gene Interactor A  \
# 0                            103                     6416
# 1                            117                    84665
# 2                            183                       90
# 3                            278                     2624
# 4                            418                     6118
# ...                          ...                      ...
# 1184828                  3585521                    22866
# 1184829                  3585522                      273
# 1184830                  3585523                    84445
# 1184831                  3585524                    23032
# 1184832                  3585525                    51562
#
#         Entrez Gene Interactor B  BioGRID ID Interactor A  \
# 0                           2318                   112315
# 1                             88                   124185
# 2                           2339                   106605
# 3                           5371                   108894
# 4                           6774                   112038
# ...                          ...                      ...
# 1184828                     1956                   116534
# 1184829                     1956                   106770
# 1184830                     1956                   124083
# 1184831                     1956                   116671
# 1184832                     1956                   119612
#
#          BioGRID ID Interactor B Systematic Name Interactor A  \
# 0                         108607                            -
# 1                         106603                            -
# 2                         108625                            -
# 3                         111384                            -
# 4                         112651                  RP4-547C9.3
# ...                          ...                          ...
# 1184828                   108276                 RP11-450P7.2
# 1184829                   108276                            -
# 1184830                   108276                 RP11-108L7.8
# 1184831                   108276                            -
# 1184832                   108276                       BM-015
#
#         Systematic Name Interactor B Official Symbol Interactor A  \
# 0                                  -                       MAP2K4
# 1                                  -                         MYPN
# 2                                  -                        ACVR1
# 3                                  -                        GATA2
# 4                                  -                         RPA2
# ...                              ...                          ...
# 1184828                            -                       CNKSR2
# 1184829                            -                         AMPH
# 1184830                            -                        LZTS2
# 1184831                            -                        USP33
# 1184832                            -                         MBIP
#
#         Official Symbol Interactor B  \
# 0                               FLNC
# 1                              ACTN2
# 2                               FNTA
# 3                                PML
# 4                              STAT3
# ...                              ...
# 1184828                         EGFR
# 1184829                         EGFR
# 1184830                         EGFR
# 1184831                         EGFR
# 1184832                         EGFR
#
#                                      Synonyms Interactor A  ...  \
# 0        JNKK|JNKK1|MAPKK4|MEK4|MKK4|PRKMK4|SAPKK-1|SAP...  ...
# 1                                   CMD1DD|CMH22|MYOP|RCM4  ...
# 2                  ACTRI|ACVR1A|ACVRLK2|ALK2|FOP|SKR1|TSRI  ...
# 3                                 DCML|IMD21|MONOMAC|NFE1B  ...
# 4                            REPA2|RP-A p32|RP-A p34|RPA32  ...
# ...                                                    ...  ...
# 1184828                                   CNK2|KSR2|MAGUIN  ...
# 1184829                                              AMPH1  ...
# 1184830                                            LAPSER1  ...
# 1184831                                               VDU1  ...
# 1184832                                                  -  ...
#
#         TREMBL Accessions Interactor B  \
# 0                               Q59H94
# 1                        Q59FD9|F6THM6
# 2                                    -
# 3                                    -
# 4                                    -
# ...                                ...
# 1184828                              -
# 1184829                              -
# 1184830                              -
# 1184831                              -
# 1184832                              -
#
#                             REFSEQ Accessions Interactor B Ontology Term IDs  \
# 0                                   NP_001120959|NP_001449                 -
# 1                      NP_001094|NP_001265272|NP_001265273                 -
# 2                                                NP_002018                 -
# 3        NP_150250|NP_150253|NP_150252|NP_150247|NP_150...                 -
# 4        NP_644805|NP_003141|NP_001356447|NP_001356443|...                 -
# ...                                                    ...               ...
# 1184828  NP_001333829|NP_001333828|NP_958440|NP_005219|...                 -
# 1184829  NP_001333829|NP_001333828|NP_958440|NP_005219|...                 -
# 1184830  NP_001333829|NP_001333828|NP_958440|NP_005219|...                 -
# 1184831  NP_001333829|NP_001333828|NP_958440|NP_005219|...                 -
# 1184832  NP_001333829|NP_001333828|NP_958440|NP_005219|...                 -
#
#         Ontology Term Names Ontology Term Categories  \
# 0                         -                        -
# 1                         -                        -
# 2                         -                        -
# 3                         -                        -
# 4                         -                        -
# ...                     ...                      ...
# 1184828                   -                        -
# 1184829                   -                        -
# 1184830                   -                        -
# 1184831                   -                        -
# 1184832                   -                        -
#
#          Ontology Term Qualifier IDs  Ontology Term Qualifier Names  \
# 0                                  -                              -
# 1                                  -                              -
# 2                                  -                              -
# 3                                  -                              -
# 4                                  -                              -
# ...                              ...                            ...
# 1184828                            -                              -
# 1184829                            -                              -
# 1184830                            -                              -
# 1184831                            -                              -
# 1184832                            -                              -
#
#         Ontology Term Types Organism Name Interactor A  \
# 0                         -               Homo sapiens
# 1                         -               Homo sapiens
# 2                         -               Homo sapiens
# 3                         -               Homo sapiens
# 4                         -               Homo sapiens
# ...                     ...                        ...
# 1184828                   -               Homo sapiens
# 1184829                   -               Homo sapiens
# 1184830                   -               Homo sapiens
# 1184831                   -               Homo sapiens
# 1184832                   -               Homo sapiens
#
#         Organism Name Interactor B
# 0                     Homo sapiens
# 1                     Homo sapiens
# 2                     Homo sapiens
# 3                     Homo sapiens
# 4                     Homo sapiens
# ...                            ...
# 1184828               Homo sapiens
# 1184829               Homo sapiens
# 1184830               Homo sapiens
# 1184831               Homo sapiens
# 1184832               Homo sapiens
#
# [1184833 rows x 37 columns]

# %%
print(Databg.columns)
# Out:
# Index(['#BioGRID Interaction ID', 'Entrez Gene Interactor A',
#        'Entrez Gene Interactor B', 'BioGRID ID Interactor A',
#        'BioGRID ID Interactor B', 'Systematic Name Interactor A',
#        'Systematic Name Interactor B', 'Official Symbol Interactor A',
#        'Official Symbol Interactor B', 'Synonyms Interactor A',
#        'Synonyms Interactor B', 'Experimental System',
#        'Experimental System Type', 'Author', 'Publication Source',
#        'Organism ID Interactor A', 'Organism ID Interactor B', 'Throughput',
#        'Score', 'Modification', 'Qualifications', 'Tags', 'Source Database',
#        'SWISS-PROT Accessions Interactor A', 'TREMBL Accessions Interactor A',
#        'REFSEQ Accessions Interactor A', 'SWISS-PROT Accessions Interactor B',
#        'TREMBL Accessions Interactor B', 'REFSEQ Accessions Interactor B',
#        'Ontology Term IDs', 'Ontology Term Names', 'Ontology Term Categories',
#        'Ontology Term Qualifier IDs', 'Ontology Term Qualifier Names',
#        'Ontology Term Types', 'Organism Name Interactor A',
#        'Organism Name Interactor B'],
#       dtype='object')

# %%
# Filtrado de las columnas que contienen las parejas de la interacción y la columna que contiene el tipo de interacción.
Databg = Databg[['Official Symbol Interactor A','Official Symbol Interactor B','Experimental System']]
print(Databg)
# Out:
#         Official Symbol Interactor A Official Symbol Interactor B  \
# 0                             MAP2K4                         FLNC
# 1                               MYPN                        ACTN2
# 2                              ACVR1                         FNTA
# 3                              GATA2                          PML
# 4                               RPA2                        STAT3
# ...                              ...                          ...
# 1184828                       CNKSR2                         EGFR
# 1184829                         AMPH                         EGFR
# 1184830                        LZTS2                         EGFR
# 1184831                        USP33                         EGFR
# 1184832                         MBIP                         EGFR
#
#               Experimental System
# 0                      Two-hybrid
# 1                      Two-hybrid
# 2                      Two-hybrid
# 3                      Two-hybrid
# 4                      Two-hybrid
# ...                           ...
# 1184828  Affinity Capture-Western
# 1184829  Affinity Capture-Western
# 1184830  Affinity Capture-Western
# 1184831  Affinity Capture-Western
# 1184832  Affinity Capture-Western
#
# [1184833 rows x 3 columns]

# %%
# Obtención de una lista con los tipos de interacción disponibles en BioGRID.
Exp_System = Databg['Experimental System'].astype('category')
Exp_System = Exp_System.unique().tolist()
print(Exp_System)
# Out:
# ['Two-hybrid', 'Affinity Capture-Luminescence', 'Affinity Capture-Western', 'Reconstituted Complex', 'Biochemical Activity', 'FRET', 'Dosage Rescue', 'Co-purification', 'Protein-peptide', 'Co-localization', 'Affinity Capture-MS', 'Affinity Capture-RNA', 'Co-crystal Structure', 'Far Western', 'Phenotypic Enhancement', 'Phenotypic Suppression', 'Co-fractionation', 'Protein-RNA', 'Synthetic Rescue', 'Synthetic Lethality', 'Synthetic Growth Defect', 'PCA', 'Dosage Lethality', 'Negative Genetic', 'Dosage Growth Defect', 'Proximity Label-MS', 'Positive Genetic']

# %%
# Obtención de las interacciones de BioGRID correspondientes a SL.
SLbg = (((Databg[Databg['Experimental System'] == 'Synthetic Lethality']).reset_index(drop = True))\
        [['Official Symbol Interactor A', 'Official Symbol Interactor B']]).rename\
            (columns = {'Official Symbol Interactor A':'n1.name', 'Official Symbol Interactor B':'n2.name'})
print(SLbg)
# Out:
#      n1.name  n2.name
# 0      SEC14     SNCA
# 1       CKI1     SNCA
# 2      FBXW7    BUB1B
# 3      FBXW7   FANCD2
# 4      FBXW7    RAB4B
# ...      ...      ...
# 2162    TP53    AP3B2
# 2163    TP53   ANXA11
# 2164     ME2      ME3
# 2165    LRP8  SLC31A1
# 2166    LRP8  SLC7A11
#
# [2167 rows x 2 columns]

# %%
SLcsv(SLbg,'BioGrid')
# Out:
# -------SL pairs for Essential PatuT Genes in BioGrid:
#
# SL pairs in BioGrid for PRMT3: No SL pairs Found
#
# SL pairs in BioGrid for ASXL1: No SL pairs Found
#
# SL pairs in BioGrid for HELLS: No SL pairs Found
#
# SL pairs in BioGrid for SMARCE1: No SL pairs Found
#
# SL pairs in BioGrid for KDM4B: No SL pairs Found
#
# SL pairs in BioGrid for EPC2: No SL pairs Found
#
# -------SL pairs for Suppressor PatuT Genes in BioGrid:
#
# SL pairs in BioGrid for WHSC1: No SL pairs Found
#
# SL pairs in BioGrid for SUV39H2: ['KRAS']
#
# -------SL pairs for Essential PatuS Genes in BioGrid:
#
# SL pairs in BioGrid for CHD7: No SL pairs Found
#
# SL pairs in BioGrid for BRD4: ['PTAR1', 'CHEK2', 'CHEK1', 'WEE1', 'CDC7', 'CDK9']
#
# SL pairs in BioGrid for ING5: ['MAP2K1', 'CDC7', 'CDK9', 'TUBA1A']
#
# -------SL pairs for Suppressor PatuS Genes in BioGrid:
#
# SL pairs in BioGrid for PHF23: No SL pairs Found
#
# SL pairs in BioGrid for UBE2A: No SL pairs Found

# %% [markdown]
# # GenomeRNAi

# %%
# Carga de los datos de GenomeRNAi
DataGRNAi = pd.read_csv(f'{work_folder}GenomeRNAi_v17_AllScreens/GenomeRNAi_v17_Homo_sapiens_clean.txt',sep = '\t')
print(DataGRNAi)
# Out:
# /tmp/ipykernel_17508/2445209705.py:1: DtypeWarning: Columns (2,5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   DataGRNAi = pd.read_csv(f'{work_folder}GenomeRNAi_v17_AllScreens/GenomeRNAi_v17_Homo_sapiens_clean.txt',sep = '\t')
#           #Stable ID Entrez ID Gene ID Gene Symbol  Reagent ID  \
# 0          GR00016-A    113510     NaN      HEL308          np
# 1          GR00016-A     57531   57531       HACE1          np
# 2          GR00016-A      9493    9493       KIF23          np
# 3          GR00016-A     57410   57410       SCYL1          np
# 4          GR00016-A     83858   83858      ATAD3B          np
# ...              ...       ...     ...         ...         ...
# 2416177  GR00402-S-2     85478   85478    NYD-SP28  SIR0014272
# 2416178  GR00402-S-2      9402    9402       GRAP2  SIR0003731
# 2416179  GR00402-S-2      4089    4089       SMAD4  SIR0001447
# 2416180  GR00402-S-2    116337  116337       PANX3  SIR0014648
# 2416181           //       NaN     NaN         NaN         NaN
#
#                         Score  \
# 0                        2.86
# 1                        2.54
# 2                        2.04
# 3                        1.54
# 4                        1.74
# ...                       ...
# 2416177  -0.40697235557445227
# 2416178     1.075584431713187
# 2416179   -0.3379224332027875
# 2416180   0.18747896419237745
# 2416181                   NaN
#
#                                                  Phenotype Conditions  \
# 0        Upregulation of Wnt/beta-catenin pathway after...        NaN
# 1        Upregulation of Wnt/beta-catenin pathway after...        NaN
# 2        Upregulation of Wnt/beta-catenin pathway after...        NaN
# 3                                                     none        NaN
# 4                                                     none        NaN
# ...                                                    ...        ...
# 2416177                                          no effect        NaN
# 2416178                                          no effect        NaN
# 2416179                                          no effect        NaN
# 2416180                                          no effect        NaN
# 2416181                                                NaN        NaN
#
#         Follow Up                Comment
# 0              no                    NaN
# 1              no                    NaN
# 2              no                    NaN
# 3              no                    NaN
# 4              no                    NaN
# ...           ...                    ...
# 2416177       NaN  5 days post-infection
# 2416178       NaN  5 days post-infection
# 2416179       NaN  5 days post-infection
# 2416180       NaN  5 days post-infection
# 2416181       NaN                    NaN
#
# [2416182 rows x 10 columns]

# %%
# Filtrado de las columnas que contienen el gen y el fenotipo inferido para cada uno como resultado de su screening.
DataGRNAi = DataGRNAi[['Gene Symbol','Phenotype']]
print(DataGRNAi)
# Out:
#         Gene Symbol                                          Phenotype
# 0            HEL308  Upregulation of Wnt/beta-catenin pathway after...
# 1             HACE1  Upregulation of Wnt/beta-catenin pathway after...
# 2             KIF23  Upregulation of Wnt/beta-catenin pathway after...
# 3             SCYL1                                               none
# 4            ATAD3B                                               none
# ...             ...                                                ...
# 2416177    NYD-SP28                                          no effect
# 2416178       GRAP2                                          no effect
# 2416179       SMAD4                                          no effect
# 2416180       PANX3                                          no effect
# 2416181         NaN                                                NaN
#
# [2416182 rows x 2 columns]

# %%
# Lista con todos los fenotipos individuales de GenomeRNAi.
Phenotypes = (DataGRNAi['Phenotype'].astype('category')).unique().tolist()
for Phe in Phenotypes:
    print(Phe)
# Out:
# Upregulation of Wnt/beta-catenin pathway after WNT3A stimulation
# none
# nan
# Phenotype
# Wnt reporter downregulated
# Wnt reporter upregulated
# Synthetic lethal with Ras
# Increased gamma-H2AX phosphorylation
# Decreased viability with paclitaxel
# Increased cell migration
# Decreased cell migration
# Decreased viability
# Decreased melanin production
# Upregulation of Wnt pathway
# Downregulation of Wnt pathway after Wnt3A stimulation
# Upregulation of Wnt pathway after Wnt3A stimulation
# Increased apoptosis
# Apoptosis resistance
# Increased proliferation
# Colony formation
# Decreased nuclei size in G2M
# Increased cell number in G2M, increased nuclei size in G2M
# Increased cell number in G1, average or increased nuclei size in G1
# Increased cell number in G1, small nuclei in G1
# Increased cell number in G2M, increased number of polyploid cells, increased number of cells with high perimeter-to-area ratio nuclei
# Increased cell number in G2M, increased number of polyploid cells
# Increased cell number in S and G2M
# Increased cell number in S
# Mitotic arrest, cytokinesis defect
# Mitotic arrest
# Mitotic arrest, spindle defect
# Cytokinesis defect
# Lethal upon entry into mitosis
# Lethal upon entry into mitosis, spindle defect
# Cell attachment phenotype
# Mitotic arrest, cytokinesis defect, spindle defect
# Increased cell growth
# Increased 8N DNA content
# Decreased cell number, increased S DNA content
# Increased G2M DNA content
# Increased G1 DNA content
# Decreased cell number, increased G1 DNA content
# Increased G2M DNA content, increased 8N DNA content
# Increased S DNA content
# Decreased cell number, increased G2M DNA content, increased 8N DNA content
# Decreased cell number
# Increased S DNA content, increased G2M DNA content
# Decreased cell number, increased G2M DNA content
# Decreased cell number, increased S DNA content, increased G2M DNA content
# Increased G1 DNA content, increased S DNA content
# Decreased cell number, increased S DNA content, increased G2M DNA content, increased 8N DNA content
# Increased S DNA content, increased 8N DNA content
# Decreased cell number, increased 8N DNA content
# Decreased cell number, increased S DNA content, increased 8N DNA content
# Increased S DNA content, increased G2M DNA content, increased 8N DNA content
# Cell division defect
# G0/1 arrest
# S arrest
# G2 arrest
# Increased number of mitotic cells
# Increased cell size
# Mitotic spindle defects
# Increased mitotic index
# Synthetic lethal with cisplatin
# Synthetic lethal with gemcitabine
# Synthetic lethal with paclitaxel
# Decreased viability with cisplatin
# Essential for multiple myeloma proliferation
# Increased cell death HMECs cells
# Increased cell death in HCT116 cells
# Increased cell death in HCC-1954 cells
# Increased cell death in DLD-1 cells
# Increased cell death in breast cancer cell lines (MCF10A, MDA-MB-435)
# Decreased viability in CMK cells
# Decreased viability in HMC1.1 cells
# Decreased viability after gemcitabine stimulation
# Decreased mitotic index
# Increased NF-kappaB reporter activity
# Increased sensitivity to paclitaxel
# Decreased sensitivity to paclitaxel
# Paclitaxel antagonistic effect
# Paclitaxel sensitizing effect
# Decreased viability with poly (ADP‐ribose)‐polymerase‐1 (PARP) inhibitor
# Increased HDAC inhibitor resistance
# Increased resistance to Trastuzumab
# Increased cell transformation
# Increased viability with tamoxifen
# Decreased viability in Von Hippel-Lindau (VHL) (-/-) cell line
# Reduced beta-catenin activity and colon cancer cell proliferation
# Increased viability with nutlin-3
# Decreased Salmonella enterica Typhimurium invasion
# Increased Salmonella enterica Typhimurium invasion
# Decreased Salmonella-containing vacuole maturation
# Increased Salmonella-containing vacuole maturation
# Decreased Salmonella enterica Typhimurium binding
# Increased Salmonella enterica Typhimurium binding
# Decreased Salmonella enterica Typhimurium effector injection
# Increased Salmonella enterica Typhimurium effector injection
# Decreased Salmonella enterica Typhimurium ruffling
# Increased Salmonella enterica Typhimurium ruffling
# Decreased Salmonella enterica Typhimurium membrane closure
# Increased Salmonella enterica Typhimurium membrane closure
# Downregulation of TNF-α/NF-κB pathway
# Decreased CXCL12 induced migration
# Increased CXCL12 induced migration
# Decreased 12E8 tau but not total tau protein expression and decreased ratio of 12E8/total tau protein expression
# Decreased 12E8 and total tau protein expression
# Decreased influenza A virus infection
# Increased influenza A virus infection
# Increased cilium length after serum starvation
# Decreased cilium length after serum starvation
# Increased cilium length
# Decreased cilium length
# Decreased homologous recombination repair frequency
# Increased homologous recombination repair frequency
# Increased viability with TRAIL
# Decreased viability with TRAIL
# Decreased CYP1A1 activity after TCDD stimulation
# Decreased telomerase activity
# Increased telomerase activity
# Decreased viability with RAF265
# Decreased p24 protein expression
# Decreased Tat-dependent transcription
# Decreased cell number and increased metaphase cell number
# High actin ratio cells
# Metaphase cells
# Actin fiber cells
# Big cells
# Large cells
# Lamellipodia cells
# Lamellipodia and high actin ratio cells
# Proliferating cells
# Bright nuclei
# Large nuclei
# Cells with protrusions
# Elongated cells
# Elongated cells with protrusions
# Abundance of large cells with protrusions and bright nuclei
# Small cells
# Low eccentricity cells
# Increased viability with paclitaxel
# Decreased Hepatitis C virus replication
# Increased Hepatitis C virus replication
# Synthetic lethal with imatinib mesylate
# Decreased POU5F1-GFP protein expression
# Decreased OCT4 protein expression
# Decreased NANOG protein expression
# Increased release from monastrol-induced mitotic arrest
# Increased viability after borna disease (rVSVΔG*/BDVG) virus infection
# Decreased substrate adherent cell growth
# Decreased influenza A/WSN/33 replication
# Decreased influenza A H1N1 (A/WSN/33) virus numbers
# Decreased influenza A H1N1 (A/Hamburg/04/2009) virus numbers
# Decreased TP53 protein expression ratio (wild-type / TP53 knockout cells)
# Decreased viability of wild-type and TP53 knockout cells
# Decreased viability of wild-type and TP53 knockout cells, decreased TP53 protein expression ratio (wild-type / TP53 knockout cells)
# Decreased viability of wild-type and TP53 knockout cells, increased TP53 protein expression ratio (wild-type / TP53 knockout cells)
# Increased TP53 protein expression ratio (wild-type / TP53 knockout cells)
# Increased HPV18 LCR reporter activity
# Decreased BPV1 E2 protein expression
# Increased number of cells in monopolar arrest with EMD534085 (a Kinesin-5 inhibitor)
# Decreased number of cells in monopolar arrest with EMD534085 (a Kinesin-5 inhibitor)
# Downregulation of NF-kappaB pathway after LMP1 stimulation
# Downregulation of NF-kappaB pathway after IL-1beta stimulation
# Downregulation of NF-kappaB pathway after TNFalpha stimulation
# Upregulation of NF-kappaB pathway after LMP1 stimulation
# Increased viability with 4OH tamoxifen
# Decreased G3BP1 protein expression and assembly in stress granules after arsenite stimulation
# Decreased DCP1a protein expression and assembly in processing bodies after arsenite stimulation
# Decreased G3BP1 protein expression and assembly in stress granules and decreased DCP1a protein expression and assembly in processing bodies after arsenite stimulation
# Increased Erk phosphorylation after EGF stimulation
# Increased Akt phosphorylation after EGF stimulation
# Increased mitotic exit time
# Decreased viability after Chlamydia trachomatis serovar L2 infection and TNF-alpha/CHX stimulation
# Decreased viability with carboplatin
# Nucleolar pre-40S maturation defects
# Nuclear pre-40S maturation defects
# Nucleoplasmic pre-40S maturation defects
# Cytoplasmic 40S maturation defects
# Nuclear 40S maturation defects
# Nuclear 60S biogenesis defects
# Altered focal adhesion (FA) or cell shape morphology
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased cell elongation, decreased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance
# Decreased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, decreased cell spreading
# Decreased focal adhesion (FA) abundance
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, decreased peripheral FA formation
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, decreased peripheral FA formation, decreased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, decreased peripheral FA formation, increased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, increased cell elongation
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, increased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, increased peripheral FA formation
# Decreased focal adhesion (FA) abundance, decreased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, increased peripheral FA formation, decreased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, increased peripheral FA formation, decreased cell elongation, decreased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, increased peripheral FA formation, decreased cell elongation
# Decreased focal adhesion (FA) abundance, increased cell elongation
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, increased peripheral FA formation, increased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, increased peripheral FA formation, increased cell elongation
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, decreased FA abundance, increased peripheral FA formation, increased cell elongation, decreased cell spreading
# Decreased focal adhesion (FA) abundance, increased cell elongation, decreased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, increased cell elongation
# Decreased focal adhesion (FA) abundance, increased cell spreading
# Decreased focal adhesion (FA) abundance, increased peripheral FA formation
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, increased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, increased FA abundance
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, increased FA abundance, decreased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, increased FA abundance, increased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, increased peripheral FA formation
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, increased peripheral FA formation, decreased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, increased peripheral FA formation, increased cell elongation
# Decreased focal adhesion (FA) area, decreased FA length, decreased FA mean intensity, increased number of small and round FAs, increased peripheral FA formation, increased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, increased number of small and round FAs
# Decreased focal adhesion (FA) area, decreased FA length, increased number of small and round FAs, decreased cell spreading
# Decreased focal adhesion (FA) area, decreased FA length, increased number of small and round FAs, decreased FA abundance, increased peripheral FA formation, increased cell elongation
# Decreased focal adhesion (FA) area, decreased FA length, increased number of small and round FAs, increased cell elongation
# Decreased focal adhesion (FA) area, decreased FA length, increased number of small and round FAs, increased peripheral FA formation, increased cell elongation
# Decreased focal adhesion (FA) area, decreased FA length, increased number of small and round FAs, increased peripheral FA formation, increased cell spreading
# Increased cell elongation
# Increased cell elongation, decreased cell spreading
# Increased cell spreading
# Increased focal adhesion (FA) abundance
# Increased focal adhesion (FA) abundance, increased cell spreading
# Increased focal adhesion (FA) area, decreased number of small and round FAs
# Increased focal adhesion (FA) area, decreased number of small and round FAs, decreased FA abundance, decreased cell spreading
# Increased focal adhesion (FA) area, decreased number of small and round FAs, decreased FA abundance, increased peripheral FA formation
# Increased focal adhesion (FA) area, decreased number of small and round FAs, decreased FA abundance, increased peripheral FA formation, decreased cell spreading
# Decreased focal adhesion (FA) abundance, increased peripheral FA formation, decreased cell elongation
# Increased focal adhesion (FA) area, decreased number of small and round FAs, increased peripheral FA formation
# Increased focal adhesion (FA) area, decreased number of small and round FAs, increased peripheral FA formation, increased cell spreading
# Increased number of small and round focal adhesions (FAs)
# Increased number of small and round focal adhesions (FAs), decreased FA abundance
# Increased number of small and round focal adhesions (FAs), decreased FA abundance, decreased cell spreading
# Increased number of small and round focal adhesions (FAs), decreased FA abundance, increased peripheral FA formation
# Increased number of small and round focal adhesions (FAs), decreased FA abundance, increased peripheral FA formation, increased cell elongation
# Increased number of small and round focal adhesions (FAs), decreased FA abundance, increased peripheral FA formation, increased cell spreading
# Increased peripheral focal adhesion (FA) formation
# Increased peripheral focal adhesion (FA) formation, increased cell elongation, decreased cell spreading
# Decreased focal adhesion (FA) abundance, increased peripheral FA formation, decreased cell spreading
# Decreased focal adhesion (FA) abundance, increased peripheral FA formation, increased cell elongation
# Decreased focal adhesion (FA) abundance, increased peripheral FA formation, increased cell elongation, decreased cell spreading
# Decreased focal adhesion (FA) abundance, increased peripheral FA formation, increased cell spreading
# Increased ID2::GFP protein expression
# Increased colony dispersion (increased number of colonies and decreased number of cells per colony)
# Increased circadian rhythm amplitude
# Increased circadian period length
# Decreased circadian period length
# Synthetic lethal with c-Myc after tamoxifen stimulation
# Increased IL-10 protein expression
# Decreased IL-10 protein expression
# Increased IL-10 protein expression, increased IFN-gamma protein expression
# Decreased IL-13 protein expression
# Increased IL-13 protein expression
# Decreased IFN-gamma protein expression
# Increased IFN-gamma protein expression
# Multipolar spindles
# Acentrosomal spindle poles
# Inhibition of centrosomal clustering
# Decreased HIV-LTR-beta-galactosidase protein expression
# Increased HIV-LTR-beta-galactosidase protein expression
# Decreased and increased HIV-LTR-beta-galactosidase protein expression
# Decreased Tat-dependent HIV-LTR-beta-galactosidase protein expression
# Decreased HIV-1 infection
# Decreased viability after TNF/CHX stimulation
# Increased viability after TNF/CHX stimulation
# Increased cell viability after pRB stimulation
# Decreased cell viability after pRB stimulation
# Increased senescence-associated beta-galactosidase protein expression after pRB stimulation
# Decreased senescence-associated beta-galactosidase protein expression after pRB stimulation
# Increased viability
# Increased ionizing radiation sensitivity
# Decreased ionizing radiation sensitivity
# Decreased viability after ionizing radiation
# Decreased JFH-1 genotype 2a Hepatitis C virus (HCV) infection
# Increased JFH-1 genotype 2a Hepatitis C virus (HCV) infection
# Decreased JFH-1 genotype 2a Hepatitis C virus (HCV) infection after direct virus infection
# Increased JFH-1 genotype 2a Hepatitis C virus (HCV) infection after direct virus infection
# Decreased JFH-1 genotype 2a Hepatitis C virus (HCV) infection after viral supernatant infection
# Increased JFH-1 genotype 2a Hepatitis C virus (HCV) infection after viral supernatant infection
# Decreased Hepatitis C Virus pseudoparticles (HCVpp; H77; genotype 1a) infection
# Decreased cell–culture–derived Hepatitis C virus (HCVcc; Luc–Jc1) infection
# Decreased viability in colon lineage
# Decreased viability in esophageal squamous lineage
# Decreased viability in esophageal squamous lineage; decreased viability in glioblastoma multiforme (GBM) lineage
# Decreased viability in esophageal squamous lineage; decreased viability in glioblastoma multiforme (GBM) lineage; decreased viability in non-small-cell lung cancer (NSCLC) lineage
# Decreased viability in esophageal squamous lineage; decreased viability in glioblastoma multiforme (GBM) lineage; decreased viability in ovarian lineage
# Decreased viability in esophageal squamous lineage; decreased viability in glioblastoma multiforme (GBM) lineage; decreased viability in pancreas lineage
# Decreased viability in esophageal squamous lineage; decreased viability in non-small-cell lung cancer (NSCLC) lineage
# Decreased viability in esophageal squamous lineage; decreased viability in non-small-cell lung cancer (NSCLC) lineage; decreased viability in ovarian lineage
# Decreased viability in esophageal squamous lineage; decreased viability in ovarian lineage
# Decreased viability in esophageal squamous lineage; decreased viability in pancreas lineage
# Decreased viability in glioblastoma multiforme (GBM) lineage
# Decreased viability in glioblastoma multiforme (GBM) lineage; decreased viability in non-small-cell lung cancer (NSCLC) lineage
# Decreased viability in glioblastoma multiforme (GBM) lineage; decreased viability in ovarian lineage
# Decreased viability in glioblastoma multiforme (GBM) lineage; decreased viability in pancreas lineage
# Decreased viability in non-small-cell lung cancer (NSCLC) lineage
# Decreased viability in non-small-cell lung cancer (NSCLC) lineage; decreased viability in ovarian lineage
# Decreased viability in non-small-cell lung cancer (NSCLC) lineage; decreased viability in ovarian lineage; decreased viability in pancreas lineage
# Decreased viability in non-small-cell lung cancer (NSCLC) lineage; decreased viability in pancreas lineage
# Decreased viability in ovarian lineage
# Decreased viability in ovarian lineage; decreased viability in pancreas lineage
# Decreased viability in pancreas lineage
# Decreased viability in colon lineage; decreased viability in esophageal squamous lineage
# Decreased viability in colon lineage; decreased viability in esophageal squamous lineage; decreased viability in pancreas lineage
# Decreased viability in colon lineage; decreased viability in glioblastoma multiforme (GBM) lineage
# Decreased viability in colon lineage; decreased viability in non-small-cell lung cancer (NSCLC) lineage
# Decreased viability in colon lineage; decreased viability in non-small-cell lung cancer (NSCLC) lineage; decreased viability in pancreas lineage
# Decreased viability in colon lineage; decreased viability in ovarian lineage
# Decreased viability in colon lineage; decreased viability in pancreas lineage
# Increased G1 length
# Increased G1 length, increased S length
# Increased S length
# Increased G1 length, increased G2 length
# Increased S length, increased G2 length
# Increased G1 length, increased S length, increased G2 length
# Increased G2 length
# Decreased vesicular stomatitis virus (VSV) infection
# Decreased lymphocytic choriomeningitis virus (LCMV) infection
# Decreased human parainfluenza virus type 3 (HPIV3) infection
# Decreased Sindbis virus (SIN) capsid and autophagosome LC3 protein colocalization
# Decreased viability after sindbis virus (SIN) dsTE12Q infection
# Decreased mitophagy mCherry-Parkin protein expression after carbonyl cyanide m-chlorphenylhydrazone (CCCP) stimulation
# Decreased Cdk9 T-loop phosphorylation
# Decreased viability with neratinib
# Increased viability with neratinib
# Increased telomere dysfunction-induced foci (TIF) formation
# FOXO1 nuclear localization
# HIV Rev nuclear localization
# Decreased human cytomegalovirus (HCMV) strain AD169 replication
# Increased human cytomegalovirus (HCMV) strain AD169 replication
# Increased vaccinia virus (VACV) infection
# Decreased vaccinia virus (VACV) infection
# Synthetic lethal with MLN4924 (a NAE inhibitor)
# Increased viability with MLN4924 (a NAE inhibitor)
# Decreased shRNA abundance
# Decreased viability after Maraba virus infection
# Decreased hepcidin::fluc mRNA expression
# Increased hepcidin::fluc mRNA expression
# Increased SMN2 exon 7 inclusion
# Negative genetic interaction between BLM-/- and BLM+/+
# Negative genetic interaction between MUS81-/- and MUS81+/+
# Negative genetic interaction between PTEN-/- and PTEN+/+
# Negative genetic interaction between PTTG1-/- and PTTG1+/+
# Negative genetic interaction between KRASG13D/+ and KRAS+/-
# Misorientated spindle
# Decreased viability (cell death)
# Dynamic nuclei (hole, folded or small irregular)
# Dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Dynamic nuclei (hole, folded or small irregular), decreased viability (cell death), increased nuclear migration speed
# Dynamic nuclei (hole, folded or small irregular), increased nuclear migration speed
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), decreased viability (cell death)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), decreased viability (cell death), increased nuclear migration speed
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), dynamic nuclei (hole, folded or small irregular)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), large nuclei
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), large nuclei, decreased viability (cell death)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), many micronuclei (grape)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), many micronuclei (grape), decreased viability (cell death)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), many micronuclei (grape), dynamic nuclei (hole, folded or small irregular)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), many micronuclei (grape), dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), many micronuclei (grape), large nuclei
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), many micronuclei (grape), large nuclei, decreased viability (cell death)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), polylobed nuclei
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), polylobed nuclei, decreased viability (cell death)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), polylobed nuclei, dynamic nuclei (hole, folded or small irregular)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), polylobed nuclei, dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), polylobed nuclei, large nuclei
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), polylobed nuclei, many micronuclei (grape)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), polylobed nuclei, many micronuclei (grape), decreased viability (cell death)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), polylobed nuclei, many micronuclei (grape), dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), polylobed nuclei, many micronuclei (grape), large nuclei
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), polylobed nuclei, many micronuclei (grape), large nuclei, decreased viability (cell death)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), two nuclei (binuclear)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), two nuclei (binuclear), many micronuclei (grape)
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), two nuclei (binuclear), polylobed nuclei
# Increased mitotic delay (prometaphase or metaphase alignment problems, MAP), two nuclei (binuclear), polylobed nuclei, many micronuclei (grape), dynamic nuclei (hole, folded or small irregular)
# Increased nuclear migration distance
# Increased nuclear migration distance, increased nuclear migration speed
# Increased nuclear migration speed
# Increased viability (proliferation)
# Increased viability (proliferation), increased nuclear migration speed
# Large nuclei, decreased viability (cell death)
# Large nuclei, dynamic nuclei (hole, folded or small irregular)
# Large nuclei, dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Large nuclei, increased nuclear migration distance
# Large nuclei, increased nuclear migration distance, increased nuclear migration speed
# Many micronuclei (grape)
# Many micronuclei (grape), decreased viability (cell death)
# Many micronuclei (grape), dynamic nuclei (hole, folded or small irregular)
# Many micronuclei (grape), dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Many micronuclei (grape), large nuclei
# Many micronuclei (grape), large nuclei, decreased viability (cell death)
# Effect on mitosis
# Effect on mitosis, decreased viability (cell death)
# Effect on mitosis, dynamic nuclei (hole, folded or small irregular)
# Effect on mitosis, increased nuclear migration speed
# Effect on mitosis, increased viability (proliferation)
# Effect on mitosis, large nuclei
# Polylobed nuclei
# Polylobed nuclei, decreased viability (cell death)
# Polylobed nuclei, dynamic nuclei (hole, folded or small irregular)
# Polylobed nuclei, dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Polylobed nuclei, increased nuclear migration speed
# Polylobed nuclei, large nuclei
# Polylobed nuclei, large nuclei, decreased viability (cell death)
# Polylobed nuclei, large nuclei, dynamic nuclei (hole, folded or small irregular)
# Polylobed nuclei, large nuclei, dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Polylobed nuclei, many micronuclei (grape)
# Polylobed nuclei, many micronuclei (grape), decreased viability (cell death)
# Polylobed nuclei, many micronuclei (grape), dynamic nuclei (hole, folded or small irregular)
# Polylobed nuclei, many micronuclei (grape), dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Polylobed nuclei, many micronuclei (grape), large nuclei
# Polylobed nuclei, many micronuclei (grape), large nuclei, decreased viability (cell death)
# Two nuclei (binuclear)
# Two nuclei (binuclear), decreased viability (cell death)
# Two nuclei (binuclear), dynamic nuclei (hole, folded or small irregular)
# Two nuclei (binuclear), dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Two nuclei (binuclear), increased nuclear migration distance, increased nuclear migration speed
# Two nuclei (binuclear), increased nuclear migration speed
# Two nuclei (binuclear), large nuclei
# Two nuclei (binuclear), many micronuclei (grape)
# Two nuclei (binuclear), many micronuclei (grape), decreased viability (cell death)
# Two nuclei (binuclear), polylobed nuclei
# Two nuclei (binuclear), polylobed nuclei, decreased viability (cell death)
# Two nuclei (binuclear), polylobed nuclei, dynamic nuclei (hole, folded or small irregular)
# Two nuclei (binuclear), polylobed nuclei, dynamic nuclei (hole, folded or small irregular), decreased viability (cell death)
# Two nuclei (binuclear), polylobed nuclei, large nuclei, dynamic nuclei (hole, folded or small irregular)
# Two nuclei (binuclear), polylobed nuclei, many micronuclei (grape)
# Two nuclei (binuclear), polylobed nuclei, many micronuclei (grape), dynamic nuclei (hole, folded or small irregular)
# Decreased viability (cell death), increased nuclear migration distance
# Decreased viability (cell death), increased nuclear migration distance, increased nuclear migration speed
# Decreased viability (cell death), increased nuclear migration speed
# Increased  Cyt C expression
# Increased centriole number
# Decreased centriole number
# Increased shRNA abundance with PLX4720
# Downregulation of RLR pathway after Sendai virus (SeV) infection
# Upregulation of RLR pathway after Sendai virus (SeV) infection
# Decreased Aire reporter expression
# Decreased human papilloma virus 16 (HPV16) pseudovirus infection
# Decreased interferon-beta reporter expression
# Increased interferon-beta reporter expression
# Decreased Sindbis virus (SINV) infection
# Increased Sindbis virus (SINV) infection
# Inconclusive
# Decreased NF-kappaB reporter expression
# Increased NF-kappaB reporter expression
# Downregulation of NFkappaB pathway
# Decreased caspase 3/7 activity
# Increased shRNA abundance
# Decreased LDL uptake
# Increased LDL uptake
# Increased free cholesterol
# Decreased free cholesterol
# shRNA abundance <= 50%
# shRNA abundance <= 25%
# Decreased Dengue Infection
# Increased Dengue infection
# Decreased infection with West Nile virus (WNV)
# Increased infection with West Nile virus (WNV)
# Increased West Nile virus (WNV) infection
# Decreased West Nile virus (WNV) infection
# Decreased HPV16-GFP infection
# Increased HPV16-GFP infection
# Resistant to vaccinia virus (VACV-A4L) infection
# Decreased vaccinia virus (VACV-LREV ) gene expression
# Decreased cell proliferation
# Increased transcriptional activity
# Increased epidermal growth factor receptor (EGFR) surface abundance
# Decreased epidermal growth factor receptor (EGFR) surface abundance
# Increased vesicular stomatitis virus (VSV) infection
# Increased simian virus 40 (SV40) infection
# Decreased simian virus 40 (SV40) infection
# Transferrin accumulation in enlarged cytoplasmic structures
# Transferrin accumulation in small spots in the cell periphery
# toxic
# Transferrin accumulation in small spots in the cell periphery, transferrin accumulation in enlarged cytoplasmic structures
# Transferrin accumulation in small spots in the cell periphery, polarized transferrin accumulation in plasma membrane protrusions
# Transferrin accumulation in the perinuclear area
# (Transferrin accumulation in small spots in the cell periphery)
# (Transferrin accumulation in enlarged cytoplasmic structures)
# (Polarized transferrin accumulation in plasma membrane protrusions)
# Polarized transferrin accumulation in plasma membrane protrusions
# (Transferrin accumulation in the perinuclear area)
# (Transferrin accumulation in small spots in the cell periphery, polarized transferrin accumulation in plasma membrane protrusions)
# Transferrin accumulation in enlarged cytoplasmic structures, polarized transferrin accumulation in plasma membrane protrusions
# Toxic, transferrin accumulation in the perinuclear area
# Weakly decreased NFAT1-GFP nuclear translocation
# Moderately decreased NFAT1-GFP nuclear translocation
# Strongly decreased NFAT1-GFP nuclear translocation
# Mildly decreased CFP-tsO45G cell surface transport
# Strongly decreased CFP-tsO45G cell surface transport
# Increased CFP-tsO45G cell surface transport
# No cells
# Decreased replication of vaccinia virus (VACV)
# Synthetic lethal with vaccinia virus (VACV) infection
# Increased replication of vaccinia virus (VACV)
# Decreased transferrin (TF) endocytosis, decreased endosome-nucleus distance (endosomes clustered in the perinuclear region)
# Increased epidermal growth factor (EGF) endocytosis, decreased endosome-nucleus distance (endosomes clustered in the perinuclear region)
# Decreased epidermal growth factor (EGF) endocytosis, decreased transferrin (TF) endocytosis
# Decreased epidermal growth factor (EGF) endocytosis
# Decreased endosome-nucleus distance (endosomes clustered in the perinuclear region)
# Decreased transferrin (TF) endocytosis
# Increased transferrin (TF) endocytosis
# Decreased epidermal growth factor (EGF) endocytosis, increased transferrin (TF) endocytosis
# Increased epidermal growth factor (EGF) endocytosis, increased transferrin (TF) endocytosis
# Increased epidermal growth factor (EGF) endocytosis, decreased transferrin (TF) endocytosis
# Increased endosome-nucleus distance (endosomes dispersed in the cell periphery)
# Increased epidermal growth factor (EGF) endocytosis
# Increased transferrin (TF) endocytosis (mild increase), increased transferrin (TF) endosome elongation
# Increased epidermal growth factor (EGF) endosome number, increased epidermal growth factor (EGF) endosome elongation
# Decreased Salmonella proliferation
# Increased Salmonella proliferation
# Diffuse trans-Golgi
# Fragmented cis-Golgi
# Condensed cis-Golgi, condensed medial Golgi, condensed trans-Golgi
# Diffuse medial Golgi
# Fragmented cis-Golgi, fragmented medial Golgi, fragmented trans-Golgi
# Condensed medial Golgi, diffuse trans-Golgi
# Diffuse cis-Golgi, diffuse trans-Golgi
# Condensed medial Golgi
# Condensed cis-Golgi, condensed medial Golgi
# Diffuse cis-Golgi
# Condensed trans-Golgi
# Fragmented cis-Golgi, fragmented medial Golgi, diffuse trans-Golgi
# Fragmented cis-Golgi, fragmented trans-Golgi
# Condensed medial Golgi, condensed trans-Golgi
# Condensed cis-Golgi
# Condensed cis-Golgi, condensed trans-Golgi
# Fragmented trans-Golgi
# Diffuse cis-Golgi, fragmented trans-Golgi
# Diffuse cis-Golgi, diffuse medial Golgi
# Diffuse cis-Golgi, fragmented medial Golgi, fragmented trans-Golgi
# Fragmented medial Golgi, fragmented trans-Golgi
# Diffuse cis-Golgi, diffuse medial Golgi, diffuse trans-Golgi
# Fragmented cis-Golgi, diffuse trans-Golgi
# Fragmented cis-Golgi, fragmented medial Golgi
# Increased shRNA abundance (Z-score > 2)
# Decreased shRNA abundance (Z-score < -2)
# Decreased viability ratio
# Reduced shRNA abundance in FBW7 KO line
# Increased Nanog expression
# Increased viability with SS1P at EC90
# Decreased viability with SS1P at EC30
# Increased virus production
# Decreased IL-8 secretion
# Increased IL-8 secretion
# Increased CDKN1A mRNA expression
# Decreased CDKN1A mRNA expression
# Increased BBC3 mRNA expression
# Decreased BBC3 mRNA expression
# Decreased TP53 mRNA expression
# Increased TP53 mRNA expression
# Reduced mammosphere formation
# Increased caspase activity
# no effect
# Increased the percentage of infected cells

# %%
# Recopilación de los fenotipos implicados en algún tipo de interacción de SL.
Phenos = []
for Phe in Phenotypes:
    if (type(Phe) is str) and ('Synthetic lethal' in Phe):
        Phenos.append(Phe)
        print(Phe[22:])

print(Phenos)
# Out:
# Ras
# cisplatin
# gemcitabine
# paclitaxel
# imatinib mesylate
# c-Myc after tamoxifen stimulation
# MLN4924 (a NAE inhibitor)
# vaccinia virus (VACV) infection
# ['Synthetic lethal with Ras', 'Synthetic lethal with cisplatin', 'Synthetic lethal with gemcitabine', 'Synthetic lethal with paclitaxel', 'Synthetic lethal with imatinib mesylate', 'Synthetic lethal with c-Myc after tamoxifen stimulation', 'Synthetic lethal with MLN4924 (a NAE inhibitor)', 'Synthetic lethal with vaccinia virus (VACV) infection']

# %%
# Filtrado de los datos de GenomeRNAi basado en los fenotipos de SL extraídos previamente.
SLGRNAi = DataGRNAi[DataGRNAi['Phenotype'].isin(Phenos)].reset_index(drop = True)
print(SLGRNAi)
# Out:
#      Gene Symbol                                          Phenotype
# 0           UBA2                          Synthetic lethal with Ras
# 1          DIDO1                          Synthetic lethal with Ras
# 2           AMFR                          Synthetic lethal with Ras
# 3         WDR42C                          Synthetic lethal with Ras
# 4         TMEM17                          Synthetic lethal with Ras
# ...          ...                                                ...
# 7249       PLCD1  Synthetic lethal with vaccinia virus (VACV) in...
# 7250        TBCA  Synthetic lethal with vaccinia virus (VACV) in...
# 7251      NHP2L1  Synthetic lethal with vaccinia virus (VACV) in...
# 7252       FOXM1  Synthetic lethal with vaccinia virus (VACV) in...
# 7253      PCOLCE  Synthetic lethal with vaccinia virus (VACV) in...
#
# [7254 rows x 2 columns]

# %%
SLGRNAi['Phenotype'] = SLGRNAi['Phenotype'].apply(lambda x: x[22:])
SLGRNAi = (SLGRNAi.drop_duplicates()).rename(columns = {'Gene Symbol':'n1.name','Phenotype':'n2.name'})
print(SLGRNAi)
# Out:
#      n1.name                          n2.name
# 0       UBA2                              Ras
# 1      DIDO1                              Ras
# 2       AMFR                              Ras
# 3     WDR42C                              Ras
# 4     TMEM17                              Ras
# ...      ...                              ...
# 7249   PLCD1  vaccinia virus (VACV) infection
# 7250    TBCA  vaccinia virus (VACV) infection
# 7251  NHP2L1  vaccinia virus (VACV) infection
# 7252   FOXM1  vaccinia virus (VACV) infection
# 7253  PCOLCE  vaccinia virus (VACV) infection
#
# [4219 rows x 2 columns]

# %%
SLcsv(SLGRNAi,'GenomeRNAi')
# Out:
# -------SL pairs for Essential PatuT Genes in GenomeRNAi:
#
# SL pairs in GenomeRNAi for PRMT3: No SL pairs Found
#
# SL pairs in GenomeRNAi for ASXL1: No SL pairs Found
#
# SL pairs in GenomeRNAi for HELLS: No SL pairs Found
#
# SL pairs in GenomeRNAi for SMARCE1: No SL pairs Found
#
# SL pairs in GenomeRNAi for KDM4B: No SL pairs Found
#
# SL pairs in GenomeRNAi for EPC2: No SL pairs Found
#
# -------SL pairs for Suppressor PatuT Genes in GenomeRNAi:
#
# SL pairs in GenomeRNAi for WHSC1: No SL pairs Found
#
# SL pairs in GenomeRNAi for SUV39H2: ['Ras']
#
# -------SL pairs for Essential PatuS Genes in GenomeRNAi:
#
# SL pairs in GenomeRNAi for CHD7: ['Ras']
#
# SL pairs in GenomeRNAi for BRD4: ['c-Myc after tamoxifen stimulation', 'MLN4924 (a NAE inhibitor)']
#
# SL pairs in GenomeRNAi for ING5: No SL pairs Found
#
# -------SL pairs for Suppressor PatuS Genes in GenomeRNAi:
#
# SL pairs in GenomeRNAi for PHF23: No SL pairs Found
#
# SL pairs in GenomeRNAi for UBE2A: ['cisplatin', 'MLN4924 (a NAE inhibitor)']

# %% [markdown]
# # Gold Standard

# %%
# Carga de los datos del GS:
SLgs = pd.read_csv(f'{work_folder}Gold_Standard/41467_2018_4647_MOESM4_ESM.csv')
print(SLgs)
# Out:
#         gene1       gene2 gene1 perturbation gene2 perturbation      PMID  \
# 0       MUS81       TTC31                mut              shRNA  24104479
# 1       MUS81       ESPL1                mut              shRNA  24104479
# 2       MUS81  ST6GALNAC3                mut              shRNA  24104479
# 3       MUS81       MTMR6                mut              shRNA  24104479
# 4       MUS81       OVCH1                mut              shRNA  24104479
# ...       ...         ...                ...                ...       ...
# 154702   ALAD      NDUFB1              sgRNA              sgRNA  28319085
# 154703  MST1R      PFKFB4              sgRNA              sgRNA  28319085
# 154704  CNTFR        NPR2              sgRNA              sgRNA  28319085
# 154705    BSG         GPI              sgRNA              sgRNA  28319085
# 154706    CA9        NPR2              sgRNA              sgRNA  28319085
#
#        cancer type tested  SL
# 0                    COAD   0
# 1                    COAD   1
# 2                    COAD   0
# 3                    COAD   0
# 4                    COAD   0
# ...                   ...  ..
# 154702               LAML   0
# 154703               LAML   0
# 154704               LAML   0
# 154705               LAML   0
# 154706               LAML   0
#
# [154707 rows x 7 columns]
# /tmp/ipykernel_17508/3506160960.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   SLgs = pd.read_csv(f'{work_folder}Gold_Standard/41467_2018_4647_MOESM4_ESM.csv')

# %%
SLgs = ((SLgs[SLgs['SL'] == 1])[['gene1', 'gene2']]).rename(columns = {'gene1':'n1.name','gene2':'n2.name'})
print(SLgs)
# Out:
#        n1.name  n2.name
# 1        MUS81    ESPL1
# 6        MUS81    TRAF6
# 9        MUS81    TRIP6
# 17       MUS81  PLEKHH1
# 20       MUS81   CREBBP
# ...        ...      ...
# 135394  CAMK2A      OXT
# 135395   BIRC5    MMP14
# 135396   KCNQ4    KDM1A
# 135397  CAMK1G   PIK3CA
# 135398  PIK3R2    STMN1
#
# [6033 rows x 2 columns]

# %%
SLcsv(SLgs,'Gold_Standard')
# Out:
# -------SL pairs for Essential PatuT Genes in Gold_Standard:
#
# SL pairs in Gold_Standard for PRMT3: No SL pairs Found
#
# SL pairs in Gold_Standard for ASXL1: ['MUS81']
#
# SL pairs in Gold_Standard for HELLS: No SL pairs Found
#
# SL pairs in Gold_Standard for SMARCE1: No SL pairs Found
#
# SL pairs in Gold_Standard for KDM4B: No SL pairs Found
#
# SL pairs in Gold_Standard for EPC2: No SL pairs Found
#
# -------SL pairs for Suppressor PatuT Genes in Gold_Standard:
#
# SL pairs in Gold_Standard for WHSC1: No SL pairs Found
#
# SL pairs in Gold_Standard for SUV39H2: ['KRAS']
#
# -------SL pairs for Essential PatuS Genes in Gold_Standard:
#
# SL pairs in Gold_Standard for CHD7: No SL pairs Found
#
# SL pairs in Gold_Standard for BRD4: ['MYC', 'MAP2K1', 'DHFR', 'FGFR3', 'KDM5C', 'PTEN', 'RB1', 'PTAR1', 'WEE1', 'CDC7', 'CDK9', 'CHEK1', 'CHEK2', 'WEE1', 'CDC7', 'CDK9', 'CHEK1', 'CHEK2', 'BRCA1']
#
# SL pairs in Gold_Standard for ING5: ['CDC7', 'CDK9', 'MAP2K1', 'TUBA1A', 'CDC7', 'CDK9', 'MAP2K1', 'TUBA1A']
#
# -------SL pairs for Suppressor PatuS Genes in Gold_Standard:
#
# SL pairs in Gold_Standard for PHF23: No SL pairs Found
#
# SL pairs in Gold_Standard for UBE2A: No SL pairs Found
